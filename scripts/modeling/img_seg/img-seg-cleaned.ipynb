# %% [markdown]
# # Find Fish Sex

# %%
# Imports
import os
import csv
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from scipy import ndimage as ndi
from scipy.ndimage import measurements, center_of_mass, binary_dilation, zoom
from skimage.segmentation import clear_border
from skimage import measure
from skimage.measure import label, regionprops
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances

# Address Memory Leak in K-means
os.environ["OMP_NUM_THREADS"] = "1"

# %%
# Select Videos
selected_videos = []
for filename in os.listdir('.'):
    if filename.endswith('.mp4'):
        selected_videos.append(filename)

# %%
# Create NPY Files with Contours for Videos
file_count = 1
for video in selected_videos:
    
    # Use OpenCV for Frame Processing
    cap = cv2.VideoCapture(video)
    frames = []
    while cap.isOpened():
        
        # Get Frame unless End of Video is Reached
        ret, frame = cap.read()
        if not ret:
            break
        
        # Convert Color Space to HSV
        hsv_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
        
        # Apply Blur
        blurred_img = cv2.GaussianBlur(hsv_frame, (3,3), 0) 
        
        # Convert to Gray for Contouring 
        gray_frame = cv2.cvtColor(blurred_img, cv2.COLOR_HSV2BGR)
        gray_frame = cv2.cvtColor(gray_frame, cv2.COLOR_BGR2GRAY)
        
        # Create Thresholding with Edges
        _, threshold_frame = cv2.threshold(gray_frame, 50, 255, cv2.THRESH_BINARY)
        edges = cv2.Canny(gray_frame, 50, 100)
        
        # Dilate the Edges for Better Contours
        kernel = np.ones((4, 4), np.uint8) 
        dilated_edges = cv2.dilate(edges, kernel, iterations=2)
        
        # Erode the Edges for Better Contours
        kernel = np.ones((4, 4), np.uint8)
        eroded_dilated_edges = cv2.erode(dilated_edges, kernel, iterations=1)
        
        # Invert the Edges so that Fish are Contoured instead of Sand
        inverted_edges = cv2.bitwise_not(eroded_dilated_edges)

        # Find the Contours 
        contours, _ = cv2.findContours(inverted_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Filter Out Small and Big Contours
        # Removes Noise and Smaller Fish Tail Contours
        contours = [contour for contour in contours if cv2.contourArea(contour) > 300]
        # Removes Tank Detections
        contours = [contour for contour in contours if cv2.contourArea(contour) < 4500]
        
        # Filter Out Extremely Round-ish Contours (like Sand)
        selected_contours = []
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            aspect_ratio = float(w) / h if h != 0 else 0
            if aspect_ratio < 1.5:
                selected_contours.append(contour)
        contours = selected_contours

        # Needed to Save the Contours to Array
        contour_frame = frame.copy()
        
        # Smooth Contours for Less Jagged Edges
        smoothed_contours = []
        for contour in contours:
            epsilon = 0.004 * cv2.arcLength(contour, True)
            approx_contour = cv2.approxPolyDP(contour, epsilon, True)
            smoothed_contours.append(approx_contour)
            
            # Use PCA to Find the Head and Tail
            # PCA Usually Finds Longest Dimension of Object (Length of Fish)
            
            # Remove Extra "Wrapper Array" from OpenCV
            points = approx_contour.reshape(-1, 2).astype(np.float32)
            
            # Ensure At Least 1 Point
            if len(points) > 1:
                
                # Compute Eigenvectors, Primary is First One; Project to Principal Axis
                mean, eigenvectors = cv2.PCACompute(points, mean=None)
                principal_axis = eigenvectors[0]
                projections = np.dot(points - mean, principal_axis)
                
                # Get Head
                max_idx = np.argmax(projections)
                head_point = tuple(points[max_idx].astype(int))

                # Get Tail
                min_idx = np.argmin(projections)
                tail_point = tuple(points[min_idx].astype(int))
                
                # Get Hues of Head and Tail
                head_hue = hsv_frame[head_point[1], head_point[0], 0]
                tail_hue = hsv_frame[tail_point[1], tail_point[0], 0]
                
                # Collect Hues from All Points
                hue_all_pts = []
                for point in points:
                    x, y = int(point[0]), int(point[1])
                    hue = hsv_frame[y, x, 0]
                    hue_all_pts.append(hue)
                hue_all_pts = np.array(hue_all_pts)
                
                # Cluster
                hue_all_pts = hue_all_pts.reshape(-1, 1)
                kmeans = KMeans(n_clusters=2, random_state=42)
                kmeans.fit(hue_all_pts)
                labels = kmeans.labels_
                centroids = kmeans.cluster_centers_
                
                # Find Intra and Between Cluster Distances
                intra_cluster_distances = []
                for i in range(2):
                    cluster_points = hue_all_pts[labels == i]
                    centroid = centroids[i]
                    distances = np.linalg.norm(cluster_points - centroid, axis=1)
                    intra_cluster_distances.append(np.mean(distances))
                between_cluster_distance = np.linalg.norm(centroids[0] - centroids[1])
                intra_cluster_distances = intra_cluster_distances[0] + intra_cluster_distances[1]
                
                # Take the SD of the Hue Values
                hue_std_dev = np.std(hue_all_pts)
                hue_range = np.max(hue_all_pts) - np.min(hue_all_pts)
                
                # Calculate Abs Value of Difference in Hue btwn Head and Tail
                # HSV has Circular Range 0-179!! Must Check Forward and Backward
                hue_dif_1 = head_hue - tail_hue
                hue_dif_2 = tail_hue - head_hue
                if (hue_dif_1 < hue_dif_2):
                    hue_dif = abs(hue_dif_1)
                else:
                    hue_dif = abs(hue_dif_2)
                
                # Print Hues to CSV for Inspection
                inspect_hue_csv = "hue_comparison.csv"
                write_header = not os.path.exists(inspect_hue_csv)
                with open(inspect_hue_csv, mode='a', newline='') as file:
                    writer = csv.writer(file)
                    
                    # Write Header
                    if write_header:
                        writer.writerow(["File Name", 
                                         "Final Hue Dif", "Hue Range", "Hue Std Dev", 
                                         "Img Seg Label", "Hue Range Label", "Hue Std Dev Label", 
                                         "Between Cluster Distance", "Intracluster Distances",
                                         "Between Cluster Label", "Intracluster Label",
                                         "Manual True Label", 
                                         "Img Seg Label Correct", "Hue Range Label Correct",
                                         "Hue Std Dev Label Correct", 
                                         "Btwn Cluster Correct", "Intra Cluster Correct"
                                        ])
                        
                    # Create True Label Column Based on File Name
                    if "female" in video.lower(): # FEMALE
                        manual_true_label = 0
                    elif "male" in video.lower(): # MALE
                        manual_true_label = 1
                        
                    # Define Function to Check Label Correctness
                    def check_label(threshold, value, true_label):
                        if value < threshold:
                            label = 0  # FEMALE
                        else:
                            label = 1  # MALE
                        correct = 1 if true_label == label else 0
                        return label, correct

                    # Apply Function to Different Features
                    hue_dif_label, hue_dif_correct = check_label(19, hue_dif, manual_true_label)
                    hue_std_dev_label, hue_std_dev_correct = check_label(10, hue_std_dev, manual_true_label)
                    hue_range_label, hue_range_correct = check_label(50, hue_range, manual_true_label) 
                    between_cluster_distance_label, between_cluster_distance_correct = check_label(10.1, between_cluster_distance, manual_true_label) 
                    intra_cluster_distance_label, intra_cluster_distance_correct = check_label(5, intra_cluster_distances, manual_true_label) 
                    
                    # Write Data to CSV
                    writer.writerow([video, 
                                     hue_dif, hue_range, hue_std_dev,
                                     hue_dif_label, hue_range_label, hue_std_dev_label, 
                                     between_cluster_distance, intra_cluster_distances,
                                     between_cluster_distance_label, intra_cluster_distance_label,
                                     manual_true_label,
                                     hue_dif_correct, hue_range_correct, 
                                     hue_std_dev_correct,
                                     between_cluster_distance_correct, intra_cluster_distance_correct])
                
                # Draw Points on Frame for Reference
                cv2.circle(contour_frame, head_point, 5, (255, 0, 0), -1)
                cv2.circle(contour_frame, tail_point, 5, (0, 0, 0), -1)
    
        # Draw Contours
        cv2.drawContours(contour_frame, smoothed_contours, -1, (0, 0, 0), 2)
    
        # Append Frames
        frames.append(contour_frame)
        
    # Release Resource
    cap.release()
    
    # Save Frames to NPY File
    frames_np = np.array(frames, dtype=np.uint8)
    np.save(f"{video}.npy", frames_np)
    
    # Get Video Info for Contour Video
    fps = 30
    height, width = frames_np.shape[1:3]

    # Video Output Name(s)
    output_file = f"{video}_CONTOUR.mp4"

    # Video Codec Info
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    # Write Frames
    out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
    for frame in frames:
        out.write(frame)
    out.release()
    
    # Print Progress
    print(f"File Number {file_count} Complete.")
    file_count = file_count + 1

# %%
# Load New Files
selected_videos = []
for filename in os.listdir('.'):
    if filename.endswith('.npy'):
        selected_videos.append(filename)

# %%
# Read in CSV of Labels and Check Frame and Track Accuracy
from collections import defaultdict
file_counts = defaultdict(lambda: {'correct': 0, 'incorrect': 0, 'total': 0, 
                                   'range_correct': 0, 'range_incorrect': 0, 'range_total': 0,
                                   'stddev_correct': 0, 'stddev_incorrect': 0, 'stddev_total': 0,
                                   'btwn_correct': 0, 'btwn_incorrect': 0, 'btwn_total': 0,
                                   'intra_correct': 0, 'intra_incorrect': 0, 'intra_total': 0})

# Find the Count of Correct and Incorrect Rows
def update_counts(file_counts, file_name, label_name, correct_key, incorrect_key, total_key):
    label_correct = row.get(label_name)
    if label_correct == '1': 
        file_counts[file_name][correct_key] += 1
    elif label_correct == '0':
        file_counts[file_name][incorrect_key] += 1
    file_counts[file_name][total_key] += 1
        
# Read Each Row
with open('hue_comparison.csv', mode='r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        file_name = row.get("File Name")

        # Update Counts for Different Features
        update_counts(file_counts, file_name, "Img Seg Label Correct", 'correct', 'incorrect', 'total')
        update_counts(file_counts, file_name, "Hue Range Label Correct", 'range_correct', 'range_incorrect', 'range_total')
        update_counts(file_counts, file_name, "Hue Std Dev Label Correct", 'stddev_correct', 'stddev_incorrect', 'stddev_total')
        update_counts(file_counts, file_name, "Btwn Cluster Correct", 'btwn_correct', 'btwn_incorrect', 'btwn_total')
        update_counts(file_counts, file_name, "Intra Cluster Correct", 'intra_correct', 'intra_incorrect', 'intra_total')

# Create Results CSV
results_csv = "results.csv"
write_header = not os.path.exists(results_csv)

# Calculate the Percentage of Rows Correct per File
def calculate_percentage_and_predict(counts, correct_key, total_key, threshold=50):
    percentage_correct = (counts[correct_key] / counts[total_key]) * 100
    print(f"File Name: {file_name} - {correct_key.replace('_', ' ').title()} Percentage Correct: {percentage_correct:.2f}%")
    prediction = 1 if percentage_correct > threshold else 0
    return percentage_correct, prediction

# Write Results to CSV
with open(results_csv, mode='a', newline='') as file:
    writer = csv.writer(file)
    
    # Write Header
    if write_header:
        writer.writerow(["File Name", "Head Tail Hue Percent Correct", "Head Tail Hue Trackwise Correct",
                        "Hue Range Percent Correct", "Hue Range Trackwise Correct",
                        "Hue Std Dev Percent Correct", "Hue Std Dev Trackwise Correct",
                        "Btwn Cluster Percent Correct", "Btwn Cluster Trackwise Correct",
                        "Intracluster Percent Correct", "Intracluster Trackwise Correct"
                        ])
        
    # Get Percentage Correct and Write to CSV
    for file_name, counts in file_counts.items():
        if counts['total'] > 0:
            percentage_correct, prediction = calculate_percentage_and_predict(counts, 'correct', 'total')
            hue_range_percent_correct, hue_range_predict = calculate_percentage_and_predict(counts, 'range_correct', 'range_total')
            hue_stddev_percent_correct, hue_stddev_predict = calculate_percentage_and_predict(counts, 'stddev_correct', 'stddev_total')
            btwn_percent_correct, btwn_predict = calculate_percentage_and_predict(counts, 'btwn_correct', 'btwn_total')
            intra_percent_correct, intra_predict = calculate_percentage_and_predict(counts, 'intra_correct', 'intra_total')
            print()
        writer.writerow([file_name, percentage_correct, prediction, 
                         hue_range_percent_correct, hue_range_predict,
                         hue_stddev_percent_correct, hue_stddev_predict,
                         btwn_percent_correct, btwn_predict,
                         intra_percent_correct, intra_predict])
# Out:
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1330_female.mp4 - Correct Percentage Correct: 92.48%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1330_female.mp4 - Range Correct Percentage Correct: 99.40%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1330_female.mp4 - Stddev Correct Percentage Correct: 90.33%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1330_female.mp4 - Btwn Correct Percentage Correct: 61.62%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1330_female.mp4 - Intra Correct Percentage Correct: 61.99%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12986_male.mp4 - Correct Percentage Correct: 13.89%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12986_male.mp4 - Range Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12986_male.mp4 - Stddev Correct Percentage Correct: 8.91%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12986_male.mp4 - Btwn Correct Percentage Correct: 80.80%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12986_male.mp4 - Intra Correct Percentage Correct: 68.15%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3969_male.mp4 - Correct Percentage Correct: 2.87%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3969_male.mp4 - Range Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3969_male.mp4 - Stddev Correct Percentage Correct: 7.17%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3969_male.mp4 - Btwn Correct Percentage Correct: 61.47%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3969_male.mp4 - Intra Correct Percentage Correct: 51.88%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3880_male.mp4 - Correct Percentage Correct: 1.72%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3880_male.mp4 - Range Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3880_male.mp4 - Stddev Correct Percentage Correct: 5.94%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3880_male.mp4 - Btwn Correct Percentage Correct: 50.27%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__3880_male.mp4 - Intra Correct Percentage Correct: 44.78%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1573_female.mp4 - Correct Percentage Correct: 93.58%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1573_female.mp4 - Range Correct Percentage Correct: 99.88%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1573_female.mp4 - Stddev Correct Percentage Correct: 94.78%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1573_female.mp4 - Btwn Correct Percentage Correct: 55.45%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1573_female.mp4 - Intra Correct Percentage Correct: 62.16%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1640_female.mp4 - Correct Percentage Correct: 98.25%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1640_female.mp4 - Range Correct Percentage Correct: 99.96%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1640_female.mp4 - Stddev Correct Percentage Correct: 99.84%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1640_female.mp4 - Btwn Correct Percentage Correct: 84.52%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1640_female.mp4 - Intra Correct Percentage Correct: 86.59%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1748_female.mp4 - Correct Percentage Correct: 93.55%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1748_female.mp4 - Range Correct Percentage Correct: 99.95%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1748_female.mp4 - Stddev Correct Percentage Correct: 92.48%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1748_female.mp4 - Btwn Correct Percentage Correct: 60.96%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__1748_female.mp4 - Intra Correct Percentage Correct: 63.52%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2085_female.mp4 - Correct Percentage Correct: 99.55%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2085_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2085_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2085_female.mp4 - Btwn Correct Percentage Correct: 89.83%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2085_female.mp4 - Intra Correct Percentage Correct: 91.44%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2090_female.mp4 - Correct Percentage Correct: 96.85%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2090_female.mp4 - Range Correct Percentage Correct: 99.49%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2090_female.mp4 - Stddev Correct Percentage Correct: 97.69%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2090_female.mp4 - Btwn Correct Percentage Correct: 63.76%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2090_female.mp4 - Intra Correct Percentage Correct: 70.23%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2095_female.mp4 - Correct Percentage Correct: 96.96%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2095_female.mp4 - Range Correct Percentage Correct: 99.83%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2095_female.mp4 - Stddev Correct Percentage Correct: 98.87%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2095_female.mp4 - Btwn Correct Percentage Correct: 71.79%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2095_female.mp4 - Intra Correct Percentage Correct: 72.13%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2962_female.mp4 - Correct Percentage Correct: 98.11%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2962_female.mp4 - Range Correct Percentage Correct: 99.98%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2962_female.mp4 - Stddev Correct Percentage Correct: 99.56%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2962_female.mp4 - Btwn Correct Percentage Correct: 81.80%
# File Name: MC_singlenuc23_1_Tk33_021220__0001_vid__2962_female.mp4 - Intra Correct Percentage Correct: 84.40%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10717_male.mp4 - Correct Percentage Correct: 74.87%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10717_male.mp4 - Range Correct Percentage Correct: 19.71%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10717_male.mp4 - Stddev Correct Percentage Correct: 80.94%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10717_male.mp4 - Btwn Correct Percentage Correct: 96.97%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10717_male.mp4 - Intra Correct Percentage Correct: 94.73%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10749_female.mp4 - Correct Percentage Correct: 90.34%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10749_female.mp4 - Range Correct Percentage Correct: 97.74%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10749_female.mp4 - Stddev Correct Percentage Correct: 94.85%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10749_female.mp4 - Btwn Correct Percentage Correct: 53.05%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10749_female.mp4 - Intra Correct Percentage Correct: 54.50%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10795_male.mp4 - Correct Percentage Correct: 62.99%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10795_male.mp4 - Range Correct Percentage Correct: 11.48%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10795_male.mp4 - Stddev Correct Percentage Correct: 74.32%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10795_male.mp4 - Btwn Correct Percentage Correct: 94.16%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__10795_male.mp4 - Intra Correct Percentage Correct: 92.82%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11688_female.mp4 - Correct Percentage Correct: 91.50%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11688_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11688_female.mp4 - Stddev Correct Percentage Correct: 96.07%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11688_female.mp4 - Btwn Correct Percentage Correct: 50.47%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11688_female.mp4 - Intra Correct Percentage Correct: 54.57%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11808_male.mp4 - Correct Percentage Correct: 56.88%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11808_male.mp4 - Range Correct Percentage Correct: 11.70%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11808_male.mp4 - Stddev Correct Percentage Correct: 67.98%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11808_male.mp4 - Btwn Correct Percentage Correct: 90.63%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__11808_male.mp4 - Intra Correct Percentage Correct: 89.38%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12384_male.mp4 - Correct Percentage Correct: 67.14%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12384_male.mp4 - Range Correct Percentage Correct: 9.71%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12384_male.mp4 - Stddev Correct Percentage Correct: 75.27%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12384_male.mp4 - Btwn Correct Percentage Correct: 95.51%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12384_male.mp4 - Intra Correct Percentage Correct: 93.02%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12696_female.mp4 - Correct Percentage Correct: 97.05%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12696_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12696_female.mp4 - Stddev Correct Percentage Correct: 99.34%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12696_female.mp4 - Btwn Correct Percentage Correct: 68.49%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12696_female.mp4 - Intra Correct Percentage Correct: 73.73%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12815_female.mp4 - Correct Percentage Correct: 92.81%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12815_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12815_female.mp4 - Stddev Correct Percentage Correct: 99.07%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12815_female.mp4 - Btwn Correct Percentage Correct: 51.25%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12815_female.mp4 - Intra Correct Percentage Correct: 58.23%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12826_male.mp4 - Correct Percentage Correct: 52.21%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12826_male.mp4 - Range Correct Percentage Correct: 5.10%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12826_male.mp4 - Stddev Correct Percentage Correct: 55.69%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12826_male.mp4 - Btwn Correct Percentage Correct: 88.51%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12826_male.mp4 - Intra Correct Percentage Correct: 88.09%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12837_female.mp4 - Correct Percentage Correct: 93.92%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12837_female.mp4 - Range Correct Percentage Correct: 99.92%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12837_female.mp4 - Stddev Correct Percentage Correct: 99.08%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12837_female.mp4 - Btwn Correct Percentage Correct: 60.05%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__12837_female.mp4 - Intra Correct Percentage Correct: 66.77%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__13039_female.mp4 - Correct Percentage Correct: 99.79%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__13039_female.mp4 - Range Correct Percentage Correct: 99.89%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__13039_female.mp4 - Stddev Correct Percentage Correct: 99.79%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__13039_female.mp4 - Btwn Correct Percentage Correct: 99.42%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__13039_female.mp4 - Intra Correct Percentage Correct: 99.89%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8931_female.mp4 - Correct Percentage Correct: 83.33%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8931_female.mp4 - Range Correct Percentage Correct: 99.13%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8931_female.mp4 - Stddev Correct Percentage Correct: 79.99%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8931_female.mp4 - Btwn Correct Percentage Correct: 28.51%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8931_female.mp4 - Intra Correct Percentage Correct: 31.88%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8981_male.mp4 - Correct Percentage Correct: 57.63%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8981_male.mp4 - Range Correct Percentage Correct: 12.10%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8981_male.mp4 - Stddev Correct Percentage Correct: 67.40%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8981_male.mp4 - Btwn Correct Percentage Correct: 90.75%
# File Name: MC_singlenuc23_1_Tk33_021220__0002_vid__8981_male.mp4 - Intra Correct Percentage Correct: 89.39%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6154_female.mp4 - Correct Percentage Correct: 91.08%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6154_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6154_female.mp4 - Stddev Correct Percentage Correct: 97.71%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6154_female.mp4 - Btwn Correct Percentage Correct: 50.96%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6154_female.mp4 - Intra Correct Percentage Correct: 56.87%
#
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6270_female.mp4 - Correct Percentage Correct: 94.94%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6270_female.mp4 - Range Correct Percentage Correct: 99.94%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6270_female.mp4 - Stddev Correct Percentage Correct: 98.25%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6270_female.mp4 - Btwn Correct Percentage Correct: 59.03%
# File Name: MC_singlenuc23_1_Tk33_021220__0003_vid__6270_female.mp4 - Intra Correct Percentage Correct: 60.77%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2244_female.mp4 - Correct Percentage Correct: 89.90%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2244_female.mp4 - Range Correct Percentage Correct: 95.85%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2244_female.mp4 - Stddev Correct Percentage Correct: 93.01%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2244_female.mp4 - Btwn Correct Percentage Correct: 65.03%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2244_female.mp4 - Intra Correct Percentage Correct: 63.73%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2340_male.mp4 - Correct Percentage Correct: 71.62%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2340_male.mp4 - Range Correct Percentage Correct: 43.92%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2340_male.mp4 - Stddev Correct Percentage Correct: 70.95%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2340_male.mp4 - Btwn Correct Percentage Correct: 87.50%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2340_male.mp4 - Intra Correct Percentage Correct: 83.45%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2344_female.mp4 - Correct Percentage Correct: 90.60%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2344_female.mp4 - Range Correct Percentage Correct: 97.34%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2344_female.mp4 - Stddev Correct Percentage Correct: 92.91%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2344_female.mp4 - Btwn Correct Percentage Correct: 61.70%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2344_female.mp4 - Intra Correct Percentage Correct: 64.36%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2345_female.mp4 - Correct Percentage Correct: 96.84%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2345_female.mp4 - Range Correct Percentage Correct: 98.95%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2345_female.mp4 - Stddev Correct Percentage Correct: 97.89%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2345_female.mp4 - Btwn Correct Percentage Correct: 61.75%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2345_female.mp4 - Intra Correct Percentage Correct: 61.75%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2460_male.mp4 - Correct Percentage Correct: 45.29%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2460_male.mp4 - Range Correct Percentage Correct: 32.06%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2460_male.mp4 - Stddev Correct Percentage Correct: 66.92%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2460_male.mp4 - Btwn Correct Percentage Correct: 74.81%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2460_male.mp4 - Intra Correct Percentage Correct: 74.05%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2466_female.mp4 - Correct Percentage Correct: 95.08%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2466_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2466_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2466_female.mp4 - Btwn Correct Percentage Correct: 74.32%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2466_female.mp4 - Intra Correct Percentage Correct: 71.31%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2467_male.mp4 - Correct Percentage Correct: 83.39%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2467_male.mp4 - Range Correct Percentage Correct: 59.47%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2467_male.mp4 - Stddev Correct Percentage Correct: 85.05%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2467_male.mp4 - Btwn Correct Percentage Correct: 94.68%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2467_male.mp4 - Intra Correct Percentage Correct: 93.69%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2489_female.mp4 - Correct Percentage Correct: 88.44%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2489_female.mp4 - Range Correct Percentage Correct: 99.11%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2489_female.mp4 - Stddev Correct Percentage Correct: 94.22%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2489_female.mp4 - Btwn Correct Percentage Correct: 71.56%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2489_female.mp4 - Intra Correct Percentage Correct: 70.67%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2647_female.mp4 - Correct Percentage Correct: 92.11%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2647_female.mp4 - Range Correct Percentage Correct: 99.25%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2647_female.mp4 - Stddev Correct Percentage Correct: 97.74%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2647_female.mp4 - Btwn Correct Percentage Correct: 65.79%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2647_female.mp4 - Intra Correct Percentage Correct: 59.02%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__277_female.mp4 - Correct Percentage Correct: 96.05%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__277_female.mp4 - Range Correct Percentage Correct: 98.81%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__277_female.mp4 - Stddev Correct Percentage Correct: 96.71%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__277_female.mp4 - Btwn Correct Percentage Correct: 70.09%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__277_female.mp4 - Intra Correct Percentage Correct: 70.22%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2865_female.mp4 - Correct Percentage Correct: 89.67%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2865_female.mp4 - Range Correct Percentage Correct: 99.18%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2865_female.mp4 - Stddev Correct Percentage Correct: 97.83%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2865_female.mp4 - Btwn Correct Percentage Correct: 63.86%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2865_female.mp4 - Intra Correct Percentage Correct: 57.61%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2866_female.mp4 - Correct Percentage Correct: 77.78%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2866_female.mp4 - Range Correct Percentage Correct: 96.22%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2866_female.mp4 - Stddev Correct Percentage Correct: 88.42%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2866_female.mp4 - Btwn Correct Percentage Correct: 60.52%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2866_female.mp4 - Intra Correct Percentage Correct: 65.48%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2928_female.mp4 - Correct Percentage Correct: 87.66%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2928_female.mp4 - Range Correct Percentage Correct: 99.50%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2928_female.mp4 - Stddev Correct Percentage Correct: 96.73%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2928_female.mp4 - Btwn Correct Percentage Correct: 67.76%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2928_female.mp4 - Intra Correct Percentage Correct: 69.27%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2929_female.mp4 - Correct Percentage Correct: 97.76%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2929_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2929_female.mp4 - Stddev Correct Percentage Correct: 99.78%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2929_female.mp4 - Btwn Correct Percentage Correct: 80.04%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2929_female.mp4 - Intra Correct Percentage Correct: 76.68%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2931_female.mp4 - Correct Percentage Correct: 97.65%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2931_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2931_female.mp4 - Stddev Correct Percentage Correct: 99.80%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2931_female.mp4 - Btwn Correct Percentage Correct: 81.57%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2931_female.mp4 - Intra Correct Percentage Correct: 83.53%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2999_female.mp4 - Correct Percentage Correct: 95.42%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2999_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2999_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2999_female.mp4 - Btwn Correct Percentage Correct: 77.12%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__2999_female.mp4 - Intra Correct Percentage Correct: 73.37%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3205_female.mp4 - Correct Percentage Correct: 99.61%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3205_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3205_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3205_female.mp4 - Btwn Correct Percentage Correct: 62.89%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3205_female.mp4 - Intra Correct Percentage Correct: 63.28%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3236_female.mp4 - Correct Percentage Correct: 87.62%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3236_female.mp4 - Range Correct Percentage Correct: 97.72%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3236_female.mp4 - Stddev Correct Percentage Correct: 97.07%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3236_female.mp4 - Btwn Correct Percentage Correct: 50.16%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__3236_female.mp4 - Intra Correct Percentage Correct: 54.72%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__493_female.mp4 - Correct Percentage Correct: 85.78%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__493_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__493_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__493_female.mp4 - Btwn Correct Percentage Correct: 55.05%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__493_female.mp4 - Intra Correct Percentage Correct: 55.50%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__494_female.mp4 - Correct Percentage Correct: 97.89%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__494_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__494_female.mp4 - Stddev Correct Percentage Correct: 98.08%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__494_female.mp4 - Btwn Correct Percentage Correct: 67.75%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__494_female.mp4 - Intra Correct Percentage Correct: 68.91%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__495_male.mp4 - Correct Percentage Correct: 72.78%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__495_male.mp4 - Range Correct Percentage Correct: 21.10%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__495_male.mp4 - Stddev Correct Percentage Correct: 79.82%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__495_male.mp4 - Btwn Correct Percentage Correct: 91.44%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__495_male.mp4 - Intra Correct Percentage Correct: 88.07%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__581_female.mp4 - Correct Percentage Correct: 91.85%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__581_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__581_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__581_female.mp4 - Btwn Correct Percentage Correct: 65.22%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__581_female.mp4 - Intra Correct Percentage Correct: 59.24%
#
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__808_male.mp4 - Correct Percentage Correct: 54.13%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__808_male.mp4 - Range Correct Percentage Correct: 19.47%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__808_male.mp4 - Stddev Correct Percentage Correct: 62.71%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__808_male.mp4 - Btwn Correct Percentage Correct: 83.50%
# File Name: MC_singlenuc23_8_Tk33_031720__0001_vid__808_male.mp4 - Intra Correct Percentage Correct: 81.52%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__299_female.mp4 - Correct Percentage Correct: 61.24%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__299_female.mp4 - Range Correct Percentage Correct: 60.59%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__299_female.mp4 - Stddev Correct Percentage Correct: 33.22%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__299_female.mp4 - Btwn Correct Percentage Correct: 3.91%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__299_female.mp4 - Intra Correct Percentage Correct: 27.04%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__454_male.mp4 - Correct Percentage Correct: 55.04%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__454_male.mp4 - Range Correct Percentage Correct: 59.67%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__454_male.mp4 - Stddev Correct Percentage Correct: 80.17%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__454_male.mp4 - Btwn Correct Percentage Correct: 98.35%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__454_male.mp4 - Intra Correct Percentage Correct: 84.63%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__541_female.mp4 - Correct Percentage Correct: 43.11%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__541_female.mp4 - Range Correct Percentage Correct: 25.39%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__541_female.mp4 - Stddev Correct Percentage Correct: 18.11%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__541_female.mp4 - Btwn Correct Percentage Correct: 5.31%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__541_female.mp4 - Intra Correct Percentage Correct: 12.99%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__574_female.mp4 - Correct Percentage Correct: 70.24%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__574_female.mp4 - Range Correct Percentage Correct: 65.87%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__574_female.mp4 - Stddev Correct Percentage Correct: 41.27%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__574_female.mp4 - Btwn Correct Percentage Correct: 8.33%
# File Name: MC_singlenuc24_4_Tk47_030320__0001_vid__574_female.mp4 - Intra Correct Percentage Correct: 20.24%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1687_male.mp4 - Correct Percentage Correct: 65.76%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1687_male.mp4 - Range Correct Percentage Correct: 80.17%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1687_male.mp4 - Stddev Correct Percentage Correct: 81.46%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1687_male.mp4 - Btwn Correct Percentage Correct: 87.02%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1687_male.mp4 - Intra Correct Percentage Correct: 81.31%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1853_female.mp4 - Correct Percentage Correct: 92.40%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1853_female.mp4 - Range Correct Percentage Correct: 81.60%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1853_female.mp4 - Stddev Correct Percentage Correct: 79.20%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1853_female.mp4 - Btwn Correct Percentage Correct: 46.00%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1853_female.mp4 - Intra Correct Percentage Correct: 66.40%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1907_male.mp4 - Correct Percentage Correct: 48.95%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1907_male.mp4 - Range Correct Percentage Correct: 67.11%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1907_male.mp4 - Stddev Correct Percentage Correct: 69.74%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1907_male.mp4 - Btwn Correct Percentage Correct: 78.42%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1907_male.mp4 - Intra Correct Percentage Correct: 72.37%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1914_female.mp4 - Correct Percentage Correct: 58.49%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1914_female.mp4 - Range Correct Percentage Correct: 47.17%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1914_female.mp4 - Stddev Correct Percentage Correct: 38.99%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1914_female.mp4 - Btwn Correct Percentage Correct: 19.50%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__1914_female.mp4 - Intra Correct Percentage Correct: 35.85%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2457_female.mp4 - Correct Percentage Correct: 64.38%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2457_female.mp4 - Range Correct Percentage Correct: 33.29%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2457_female.mp4 - Stddev Correct Percentage Correct: 30.18%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2457_female.mp4 - Btwn Correct Percentage Correct: 15.16%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2457_female.mp4 - Intra Correct Percentage Correct: 22.28%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2489_male.mp4 - Correct Percentage Correct: 71.18%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2489_male.mp4 - Range Correct Percentage Correct: 89.54%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2489_male.mp4 - Stddev Correct Percentage Correct: 90.65%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2489_male.mp4 - Btwn Correct Percentage Correct: 94.00%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__2489_male.mp4 - Intra Correct Percentage Correct: 89.97%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3130_female.mp4 - Correct Percentage Correct: 60.27%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3130_female.mp4 - Range Correct Percentage Correct: 41.08%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3130_female.mp4 - Stddev Correct Percentage Correct: 32.66%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3130_female.mp4 - Btwn Correct Percentage Correct: 16.16%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3130_female.mp4 - Intra Correct Percentage Correct: 32.32%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3261_male.mp4 - Correct Percentage Correct: 53.77%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3261_male.mp4 - Range Correct Percentage Correct: 71.51%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3261_male.mp4 - Stddev Correct Percentage Correct: 72.45%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3261_male.mp4 - Btwn Correct Percentage Correct: 81.32%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3261_male.mp4 - Intra Correct Percentage Correct: 72.83%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3394_male.mp4 - Correct Percentage Correct: 81.96%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3394_male.mp4 - Range Correct Percentage Correct: 94.78%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3394_male.mp4 - Stddev Correct Percentage Correct: 95.73%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3394_male.mp4 - Btwn Correct Percentage Correct: 98.42%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3394_male.mp4 - Intra Correct Percentage Correct: 94.94%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3425_male.mp4 - Correct Percentage Correct: 72.51%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3425_male.mp4 - Range Correct Percentage Correct: 85.31%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3425_male.mp4 - Stddev Correct Percentage Correct: 86.73%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3425_male.mp4 - Btwn Correct Percentage Correct: 89.10%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3425_male.mp4 - Intra Correct Percentage Correct: 88.15%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3426_female.mp4 - Correct Percentage Correct: 49.71%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3426_female.mp4 - Range Correct Percentage Correct: 26.90%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3426_female.mp4 - Stddev Correct Percentage Correct: 19.88%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3426_female.mp4 - Btwn Correct Percentage Correct: 5.26%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3426_female.mp4 - Intra Correct Percentage Correct: 12.87%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__349_female.mp4 - Correct Percentage Correct: 34.80%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__349_female.mp4 - Range Correct Percentage Correct: 4.40%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__349_female.mp4 - Stddev Correct Percentage Correct: 2.00%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__349_female.mp4 - Btwn Correct Percentage Correct: 1.20%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__349_female.mp4 - Intra Correct Percentage Correct: 6.80%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3553_male.mp4 - Correct Percentage Correct: 53.59%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3553_male.mp4 - Range Correct Percentage Correct: 76.86%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3553_male.mp4 - Stddev Correct Percentage Correct: 77.34%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3553_male.mp4 - Btwn Correct Percentage Correct: 89.28%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__3553_male.mp4 - Intra Correct Percentage Correct: 80.02%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__451_male.mp4 - Correct Percentage Correct: 51.05%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__451_male.mp4 - Range Correct Percentage Correct: 70.53%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__451_male.mp4 - Stddev Correct Percentage Correct: 71.58%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__451_male.mp4 - Btwn Correct Percentage Correct: 77.63%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__451_male.mp4 - Intra Correct Percentage Correct: 70.79%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6822_male.mp4 - Correct Percentage Correct: 63.56%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6822_male.mp4 - Range Correct Percentage Correct: 82.45%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6822_male.mp4 - Stddev Correct Percentage Correct: 82.71%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6822_male.mp4 - Btwn Correct Percentage Correct: 89.36%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6822_male.mp4 - Intra Correct Percentage Correct: 83.78%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6833_female.mp4 - Correct Percentage Correct: 69.94%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6833_female.mp4 - Range Correct Percentage Correct: 42.63%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6833_female.mp4 - Stddev Correct Percentage Correct: 40.08%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6833_female.mp4 - Btwn Correct Percentage Correct: 28.29%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__6833_female.mp4 - Intra Correct Percentage Correct: 38.11%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__767_male.mp4 - Correct Percentage Correct: 74.87%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__767_male.mp4 - Range Correct Percentage Correct: 86.63%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__767_male.mp4 - Stddev Correct Percentage Correct: 87.17%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__767_male.mp4 - Btwn Correct Percentage Correct: 91.44%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__767_male.mp4 - Intra Correct Percentage Correct: 88.77%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__82_female.mp4 - Correct Percentage Correct: 82.85%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__82_female.mp4 - Range Correct Percentage Correct: 68.75%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__82_female.mp4 - Stddev Correct Percentage Correct: 64.58%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__82_female.mp4 - Btwn Correct Percentage Correct: 43.43%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__82_female.mp4 - Intra Correct Percentage Correct: 54.65%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__85_male.mp4 - Correct Percentage Correct: 58.48%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__85_male.mp4 - Range Correct Percentage Correct: 74.69%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__85_male.mp4 - Stddev Correct Percentage Correct: 75.44%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__85_male.mp4 - Btwn Correct Percentage Correct: 86.53%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__85_male.mp4 - Intra Correct Percentage Correct: 77.81%
#
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__97_female.mp4 - Correct Percentage Correct: 55.56%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__97_female.mp4 - Range Correct Percentage Correct: 35.10%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__97_female.mp4 - Stddev Correct Percentage Correct: 27.53%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__97_female.mp4 - Btwn Correct Percentage Correct: 6.57%
# File Name: MC_singlenuc24_4_Tk47_030320__0002_vid__97_female.mp4 - Intra Correct Percentage Correct: 17.42%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0001_vid__3093_male.mp4 - Correct Percentage Correct: 61.86%
# File Name: MC_singlenuc28_1_Tk3_022520__0001_vid__3093_male.mp4 - Range Correct Percentage Correct: 75.52%
# File Name: MC_singlenuc28_1_Tk3_022520__0001_vid__3093_male.mp4 - Stddev Correct Percentage Correct: 82.71%
# File Name: MC_singlenuc28_1_Tk3_022520__0001_vid__3093_male.mp4 - Btwn Correct Percentage Correct: 93.58%
# File Name: MC_singlenuc28_1_Tk3_022520__0001_vid__3093_male.mp4 - Intra Correct Percentage Correct: 87.83%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__19583_male.mp4 - Correct Percentage Correct: 68.43%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__19583_male.mp4 - Range Correct Percentage Correct: 77.89%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__19583_male.mp4 - Stddev Correct Percentage Correct: 83.82%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__19583_male.mp4 - Btwn Correct Percentage Correct: 93.80%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__19583_male.mp4 - Intra Correct Percentage Correct: 88.66%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__20243_male.mp4 - Correct Percentage Correct: 71.33%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__20243_male.mp4 - Range Correct Percentage Correct: 77.11%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__20243_male.mp4 - Stddev Correct Percentage Correct: 85.19%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__20243_male.mp4 - Btwn Correct Percentage Correct: 95.92%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__20243_male.mp4 - Intra Correct Percentage Correct: 93.70%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__25421_male.mp4 - Correct Percentage Correct: 61.42%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__25421_male.mp4 - Range Correct Percentage Correct: 68.66%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__25421_male.mp4 - Stddev Correct Percentage Correct: 76.13%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__25421_male.mp4 - Btwn Correct Percentage Correct: 86.59%
# File Name: MC_singlenuc28_1_Tk3_022520__0002_vid__25421_male.mp4 - Intra Correct Percentage Correct: 82.45%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__13622_male.mp4 - Correct Percentage Correct: 63.11%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__13622_male.mp4 - Range Correct Percentage Correct: 71.42%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__13622_male.mp4 - Stddev Correct Percentage Correct: 79.21%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__13622_male.mp4 - Btwn Correct Percentage Correct: 90.04%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__13622_male.mp4 - Intra Correct Percentage Correct: 86.34%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__14195_female.mp4 - Correct Percentage Correct: 62.89%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__14195_female.mp4 - Range Correct Percentage Correct: 60.92%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__14195_female.mp4 - Stddev Correct Percentage Correct: 40.06%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__14195_female.mp4 - Btwn Correct Percentage Correct: 18.77%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__14195_female.mp4 - Intra Correct Percentage Correct: 29.18%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__15562_male.mp4 - Correct Percentage Correct: 61.42%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__15562_male.mp4 - Range Correct Percentage Correct: 64.21%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__15562_male.mp4 - Stddev Correct Percentage Correct: 77.76%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__15562_male.mp4 - Btwn Correct Percentage Correct: 88.95%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__15562_male.mp4 - Intra Correct Percentage Correct: 82.93%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__19722_female.mp4 - Correct Percentage Correct: 68.64%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__19722_female.mp4 - Range Correct Percentage Correct: 58.78%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__19722_female.mp4 - Stddev Correct Percentage Correct: 44.74%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__19722_female.mp4 - Btwn Correct Percentage Correct: 17.40%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__19722_female.mp4 - Intra Correct Percentage Correct: 31.36%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__22173_female.mp4 - Correct Percentage Correct: 64.63%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__22173_female.mp4 - Range Correct Percentage Correct: 64.69%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__22173_female.mp4 - Stddev Correct Percentage Correct: 34.00%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__22173_female.mp4 - Btwn Correct Percentage Correct: 9.20%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__22173_female.mp4 - Intra Correct Percentage Correct: 18.23%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23531_female.mp4 - Correct Percentage Correct: 76.83%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23531_female.mp4 - Range Correct Percentage Correct: 85.77%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23531_female.mp4 - Stddev Correct Percentage Correct: 56.50%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23531_female.mp4 - Btwn Correct Percentage Correct: 28.05%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23531_female.mp4 - Intra Correct Percentage Correct: 38.05%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23594_female.mp4 - Correct Percentage Correct: 72.12%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23594_female.mp4 - Range Correct Percentage Correct: 73.88%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23594_female.mp4 - Stddev Correct Percentage Correct: 45.93%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23594_female.mp4 - Btwn Correct Percentage Correct: 16.65%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23594_female.mp4 - Intra Correct Percentage Correct: 29.35%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23931_female.mp4 - Correct Percentage Correct: 69.61%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23931_female.mp4 - Range Correct Percentage Correct: 70.63%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23931_female.mp4 - Stddev Correct Percentage Correct: 49.91%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23931_female.mp4 - Btwn Correct Percentage Correct: 18.87%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__23931_female.mp4 - Intra Correct Percentage Correct: 31.22%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24342_female.mp4 - Correct Percentage Correct: 67.82%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24342_female.mp4 - Range Correct Percentage Correct: 65.23%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24342_female.mp4 - Stddev Correct Percentage Correct: 47.19%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24342_female.mp4 - Btwn Correct Percentage Correct: 19.17%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24342_female.mp4 - Intra Correct Percentage Correct: 34.45%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24668_male.mp4 - Correct Percentage Correct: 67.66%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24668_male.mp4 - Range Correct Percentage Correct: 79.27%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24668_male.mp4 - Stddev Correct Percentage Correct: 87.08%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24668_male.mp4 - Btwn Correct Percentage Correct: 96.50%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__24668_male.mp4 - Intra Correct Percentage Correct: 91.42%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25037_male.mp4 - Correct Percentage Correct: 59.97%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25037_male.mp4 - Range Correct Percentage Correct: 70.08%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25037_male.mp4 - Stddev Correct Percentage Correct: 82.79%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25037_male.mp4 - Btwn Correct Percentage Correct: 94.52%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25037_male.mp4 - Intra Correct Percentage Correct: 88.36%
#
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25054_female.mp4 - Correct Percentage Correct: 74.92%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25054_female.mp4 - Range Correct Percentage Correct: 76.49%
# File Name: MC_singlenuc28_1_Tk3_022520__0003_vid__25054_female.mp4 - Stddev Correct Percentage Correct: 57.89%
# ...
# File Name: MC_singlenuc34_3_Tk43_030320__0001_vid__9351_male.mp4 - Btwn Correct Percentage Correct: 32.23%
# File Name: MC_singlenuc34_3_Tk43_030320__0001_vid__9351_male.mp4 - Intra Correct Percentage Correct: 16.53%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2402_female.mp4 - Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2402_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2402_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2402_female.mp4 - Btwn Correct Percentage Correct: 99.31%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2402_female.mp4 - Intra Correct Percentage Correct: 99.76%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2433_male.mp4 - Correct Percentage Correct: 13.37%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2433_male.mp4 - Range Correct Percentage Correct: 6.31%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2433_male.mp4 - Stddev Correct Percentage Correct: 61.92%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2433_male.mp4 - Btwn Correct Percentage Correct: 98.87%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__2433_male.mp4 - Intra Correct Percentage Correct: 94.96%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4003_female.mp4 - Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4003_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4003_female.mp4 - Stddev Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4003_female.mp4 - Btwn Correct Percentage Correct: 99.90%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4003_female.mp4 - Intra Correct Percentage Correct: 99.59%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4296_female.mp4 - Correct Percentage Correct: 98.51%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4296_female.mp4 - Range Correct Percentage Correct: 98.37%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4296_female.mp4 - Stddev Correct Percentage Correct: 98.37%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4296_female.mp4 - Btwn Correct Percentage Correct: 97.51%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4296_female.mp4 - Intra Correct Percentage Correct: 97.80%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4573_male.mp4 - Correct Percentage Correct: 2.99%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4573_male.mp4 - Range Correct Percentage Correct: 0.14%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4573_male.mp4 - Stddev Correct Percentage Correct: 12.51%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4573_male.mp4 - Btwn Correct Percentage Correct: 70.81%
# File Name: MC_singlenuc35_11_Tk61_051220__0001_vid__4573_male.mp4 - Intra Correct Percentage Correct: 60.43%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1581_male.mp4 - Correct Percentage Correct: 29.73%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1581_male.mp4 - Range Correct Percentage Correct: 19.91%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1581_male.mp4 - Stddev Correct Percentage Correct: 78.47%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1581_male.mp4 - Btwn Correct Percentage Correct: 89.85%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1581_male.mp4 - Intra Correct Percentage Correct: 88.29%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1635_female.mp4 - Correct Percentage Correct: 99.63%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1635_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1635_female.mp4 - Stddev Correct Percentage Correct: 99.39%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1635_female.mp4 - Btwn Correct Percentage Correct: 97.55%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1635_female.mp4 - Intra Correct Percentage Correct: 98.41%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1637_male.mp4 - Correct Percentage Correct: 34.91%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1637_male.mp4 - Range Correct Percentage Correct: 29.95%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1637_male.mp4 - Stddev Correct Percentage Correct: 89.17%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1637_male.mp4 - Btwn Correct Percentage Correct: 95.97%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__1637_male.mp4 - Intra Correct Percentage Correct: 95.28%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2102_female.mp4 - Correct Percentage Correct: 97.99%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2102_female.mp4 - Range Correct Percentage Correct: 100.00%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2102_female.mp4 - Stddev Correct Percentage Correct: 99.48%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2102_female.mp4 - Btwn Correct Percentage Correct: 93.50%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2102_female.mp4 - Intra Correct Percentage Correct: 95.46%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2105_male.mp4 - Correct Percentage Correct: 23.93%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2105_male.mp4 - Range Correct Percentage Correct: 16.65%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2105_male.mp4 - Stddev Correct Percentage Correct: 76.99%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2105_male.mp4 - Btwn Correct Percentage Correct: 87.86%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__2105_male.mp4 - Intra Correct Percentage Correct: 87.63%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3257_female.mp4 - Correct Percentage Correct: 96.71%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3257_female.mp4 - Range Correct Percentage Correct: 99.79%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3257_female.mp4 - Stddev Correct Percentage Correct: 96.43%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3257_female.mp4 - Btwn Correct Percentage Correct: 89.43%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3257_female.mp4 - Intra Correct Percentage Correct: 92.79%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3267_male.mp4 - Correct Percentage Correct: 45.15%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3267_male.mp4 - Range Correct Percentage Correct: 37.39%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3267_male.mp4 - Stddev Correct Percentage Correct: 92.03%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3267_male.mp4 - Btwn Correct Percentage Correct: 95.69%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__3267_male.mp4 - Intra Correct Percentage Correct: 94.72%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__45_female.mp4 - Correct Percentage Correct: 98.33%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__45_female.mp4 - Range Correct Percentage Correct: 99.64%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__45_female.mp4 - Stddev Correct Percentage Correct: 98.45%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__45_female.mp4 - Btwn Correct Percentage Correct: 92.71%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__45_female.mp4 - Intra Correct Percentage Correct: 95.58%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__47_male.mp4 - Correct Percentage Correct: 34.83%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__47_male.mp4 - Range Correct Percentage Correct: 40.72%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__47_male.mp4 - Stddev Correct Percentage Correct: 90.92%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__47_male.mp4 - Btwn Correct Percentage Correct: 95.01%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__47_male.mp4 - Intra Correct Percentage Correct: 94.61%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__612_male.mp4 - Correct Percentage Correct: 34.78%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__612_male.mp4 - Range Correct Percentage Correct: 23.65%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__612_male.mp4 - Stddev Correct Percentage Correct: 85.89%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__612_male.mp4 - Btwn Correct Percentage Correct: 96.26%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__612_male.mp4 - Intra Correct Percentage Correct: 95.35%
#
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__622_female.mp4 - Correct Percentage Correct: 95.31%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__622_female.mp4 - Range Correct Percentage Correct: 98.34%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__622_female.mp4 - Stddev Correct Percentage Correct: 93.45%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__622_female.mp4 - Btwn Correct Percentage Correct: 90.22%
# File Name: MC_singlenuc35_11_Tk61_051220__0002_vid__622_female.mp4 - Intra Correct Percentage Correct: 91.30%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__15401_female.mp4 - Correct Percentage Correct: 62.89%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__15401_female.mp4 - Range Correct Percentage Correct: 56.67%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__15401_female.mp4 - Stddev Correct Percentage Correct: 49.78%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__15401_female.mp4 - Btwn Correct Percentage Correct: 32.00%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__15401_female.mp4 - Intra Correct Percentage Correct: 45.22%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__17478_female.mp4 - Correct Percentage Correct: 58.28%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__17478_female.mp4 - Range Correct Percentage Correct: 55.92%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__17478_female.mp4 - Stddev Correct Percentage Correct: 27.22%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__17478_female.mp4 - Btwn Correct Percentage Correct: 15.68%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__17478_female.mp4 - Intra Correct Percentage Correct: 21.30%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18777_female.mp4 - Correct Percentage Correct: 82.52%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18777_female.mp4 - Range Correct Percentage Correct: 76.96%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18777_female.mp4 - Stddev Correct Percentage Correct: 66.40%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18777_female.mp4 - Btwn Correct Percentage Correct: 32.66%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18777_female.mp4 - Intra Correct Percentage Correct: 49.59%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18918_female.mp4 - Correct Percentage Correct: 73.56%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18918_female.mp4 - Range Correct Percentage Correct: 69.69%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18918_female.mp4 - Stddev Correct Percentage Correct: 50.77%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18918_female.mp4 - Btwn Correct Percentage Correct: 27.88%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18918_female.mp4 - Intra Correct Percentage Correct: 43.36%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18919_female.mp4 - Correct Percentage Correct: 64.85%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18919_female.mp4 - Range Correct Percentage Correct: 63.72%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18919_female.mp4 - Stddev Correct Percentage Correct: 46.03%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18919_female.mp4 - Btwn Correct Percentage Correct: 17.23%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18919_female.mp4 - Intra Correct Percentage Correct: 37.64%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18958_female.mp4 - Correct Percentage Correct: 57.55%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18958_female.mp4 - Range Correct Percentage Correct: 51.35%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18958_female.mp4 - Stddev Correct Percentage Correct: 35.10%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18958_female.mp4 - Btwn Correct Percentage Correct: 19.76%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__18958_female.mp4 - Intra Correct Percentage Correct: 29.96%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19024_female.mp4 - Correct Percentage Correct: 73.91%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19024_female.mp4 - Range Correct Percentage Correct: 72.42%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19024_female.mp4 - Stddev Correct Percentage Correct: 61.01%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19024_female.mp4 - Btwn Correct Percentage Correct: 32.20%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19024_female.mp4 - Intra Correct Percentage Correct: 52.99%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19592_female.mp4 - Correct Percentage Correct: 77.83%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19592_female.mp4 - Range Correct Percentage Correct: 74.49%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19592_female.mp4 - Stddev Correct Percentage Correct: 67.54%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19592_female.mp4 - Btwn Correct Percentage Correct: 42.46%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__19592_female.mp4 - Intra Correct Percentage Correct: 60.72%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__21205_female.mp4 - Correct Percentage Correct: 83.90%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__21205_female.mp4 - Range Correct Percentage Correct: 79.83%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__21205_female.mp4 - Stddev Correct Percentage Correct: 73.39%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__21205_female.mp4 - Btwn Correct Percentage Correct: 48.98%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__21205_female.mp4 - Intra Correct Percentage Correct: 63.90%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__2837_male.mp4 - Correct Percentage Correct: 86.67%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__2837_male.mp4 - Range Correct Percentage Correct: 87.04%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__2837_male.mp4 - Stddev Correct Percentage Correct: 94.63%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__2837_male.mp4 - Btwn Correct Percentage Correct: 99.26%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__2837_male.mp4 - Intra Correct Percentage Correct: 99.07%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__291_male.mp4 - Correct Percentage Correct: 83.34%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__291_male.mp4 - Range Correct Percentage Correct: 92.02%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__291_male.mp4 - Stddev Correct Percentage Correct: 95.60%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__291_male.mp4 - Btwn Correct Percentage Correct: 98.65%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__291_male.mp4 - Intra Correct Percentage Correct: 96.72%
#
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__6367_male.mp4 - Correct Percentage Correct: 81.82%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__6367_male.mp4 - Range Correct Percentage Correct: 91.66%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__6367_male.mp4 - Stddev Correct Percentage Correct: 95.19%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__6367_male.mp4 - Btwn Correct Percentage Correct: 99.25%
# File Name: MC_singlenuc36_2_Tk3_030320__0001_vid__6367_male.mp4 - Intra Correct Percentage Correct: 98.07%
#
# File Name: MC_singlenuc96_b1_Tk41_081120__0001_vid__9350_male.mp4 - Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc96_b1_Tk41_081120__0001_vid__9350_male.mp4 - Range Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc96_b1_Tk41_081120__0001_vid__9350_male.mp4 - Stddev Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc96_b1_Tk41_081120__0001_vid__9350_male.mp4 - Btwn Correct Percentage Correct: 0.00%
# File Name: MC_singlenuc96_b1_Tk41_081120__0001_vid__9350_male.mp4 - Intra Correct Percentage Correct: 0.00%

# %%
# Get Total Result Counts
df = pd.read_csv("results.csv")
total_valid_rows = df.dropna().shape[0]

# Get Counts for Each Feature
headtailhue_trackwise_correct_count = (df['Head Tail Hue Trackwise Correct'] == 1).sum()
huerange_trackwise_correct_count = (df['Hue Range Trackwise Correct'] == 1).sum()
huestddev_trackwise_correct_count = (df['Hue Std Dev Trackwise Correct'] == 1).sum()
btwn_trackwise_correct_count = (df['Btwn Cluster Trackwise Correct'] == 1).sum()
intra_trackwise_correct_count = (df['Intracluster Trackwise Correct'] == 1).sum()

# Percentage Correct
print(f"Head Tail Hue Dif Trackwise Percentage Correct: {headtailhue_trackwise_correct_count / total_valid_rows}")
print(f"Hue Range Trackwise Percentage Correct: {huerange_trackwise_correct_count / total_valid_rows}")
print(f"Hue Std Dev Trackwise Percentage Correct: {huestddev_trackwise_correct_count / total_valid_rows}")
print(f"Btwn Cluster Trackwise Percentage Correct: {btwn_trackwise_correct_count / total_valid_rows}")
print(f"Intracluster Trackwise Percentage Correct: {intra_trackwise_correct_count / total_valid_rows}")
# Out:
# Head Tail Hue Dif Trackwise Percentage Correct: 0.8214285714285714
# Hue Range Trackwise Percentage Correct: 0.7214285714285714
# Hue Std Dev Trackwise Percentage Correct: 0.7357142857142858
# Btwn Cluster Trackwise Percentage Correct: 0.7285714285714285
# Intracluster Trackwise Percentage Correct: 0.75

# %% [markdown]
# TODO Next:
# 1) Choose train and test.
# 2) Using train, choose threshold values for head/tail hue differenct, hue range, hue std, btwn cluster distance, and intracluster distance.
# 3) Sort intracluster distances by size and try thresholding both OR try new clustering algorithm.
# 4) Choose the 2 or 3 best methods and run through neural net or something simple that can be trained with around 100 samples in train.
# 5) Integrate with Eric's existing method for the outline. This may take some time. Note that the errors appear to be mostly from the coloration being difficult, not tank detections.
# 6) Tune contour filtering, contour smoothing, and contour aspect ratio elimination.

# %% [markdown]
# Sources will be listed in their associated cells. Some generative ai was used to assist in writing code. The following tutorial was used as a starting point: https://www.youtube.com/watch?v=UIgaLDgb2fYv.
