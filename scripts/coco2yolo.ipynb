# %% [markdown]
# # COCO to YOLO Conversion
#
# Useful in converting COCO-formatted datasets into YOLO-format.
#
# Make sure to erase existing YOLOv5 dataset (if any) BEFORE running this notebook.
#
# **Author:** Charlie Clark \
# **Email:** cclark339@gatech.edu

# %%
from typing import Tuple, Dict, List
import os, json, shutil
import tqdm

import numpy as np
import cv2

import matplotlib.pyplot as plt

# %% [markdown]
# ## Parameters
#
# **SRC:** the *full* filepath to the coco JSON file. \
# **IMGS:** the *full* path to the directory containing the images. \
# **DEST:** the *full* path to the directory where the YOLO data will be stored.

# %%
SRC = '/home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_coco/train.json' # change as needed
IMGS = '/home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_coco/images/' # change as needed
DEST = '/home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_yolo/' # change as needed
mode = 'train' # change as needed

assert mode in ['train', 'val'], f'Error: mode must either be "train" or "val" (got "{mode}")'

# %% [markdown]
# ## CAUTION!
#
# Unless you've thoroughly reviewed the code and understand how it works, please do NOT change anything below this line.
#
# For inquiries, reach out to me on Slack or via my email at the top of this notebook.

# %% [markdown]
# ## Preparation and EDA

# %%
IMGS = IMGS.rstrip('/') + '/'
DEST = DEST.rstrip('/') + '/'

print(f'IMGS: {IMGS}')
print(f'DEST: {DEST}')
# Out:
# IMGS: /home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_coco/images/
# DEST: /home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_yolo/

# %%
DEST_IMGS = DEST + f'images/'
DEST_LABS = DEST + f'labels/'

print(f'DEST_IMGS: {DEST_IMGS}')
print(f'DEST_LABS: {DEST_LABS}')
# Out:
# DEST_IMGS: /home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_yolo/images/
# DEST_LABS: /home/hice1/cclark339/scratch/Data/Lindenthal_Camera_Traps/lindenthal-camera-traps/lindenthal_yolo/labels/

# %%
if not os.path.exists(DEST):
    os.mkdir(DEST)
    os.mkdir(DEST_IMGS)
    os.mkdir(DEST_LABS)

DEST_IMGS += f'{mode}/'
DEST_LABS += f'{mode}/'

if not os.path.exists(DEST_IMGS) and not os.path.exists(DEST_LABS):
    os.mkdir(DEST_IMGS)
    os.mkdir(DEST_LABS)

# %%
with open(SRC, 'r') as f:
    data = json.load(f)

print(f'JSON keys: {list(data.keys())}')
# Out:
# JSON keys: ['annotations', 'images', 'licenses', 'info', 'categories']

# %%
data_annotations = data['annotations']
data_images = data['images']
data_categories = data['categories']

# %%
data_annotations[0]
# Out:
# {'id': 458,
#  'image_id': '20200807023726-31',
#  'category_id': 2,
#  'segmentation': [[432.21,
#    240.17,
#    433.6,
#    239.66,
#    433.85,
#    238.15,
#    432.97,
#    236.38,
#    432.46,
#    234.61,
#    434.74,
#    234.86,
#    435.49,
#    236.76,
#    435.87,
#    240.55,
#    435.72,
#    243.71,
#    435.22,
#    246.01,
#    435.42,
#    248.9,
#    435.82,
#    251.81,
#    434.62,
#    253.91,
#    432.42,
#    254.4,
#    431.42,
#    253.2,
#    429.43,
#    251.61,
#    428.43,
#    249.8,
#    426.52,
#    248.8,
#    424.82,
#    247.41,
#    422.42,
#    245.4,
#    419.22,
#    243.1,
#    418.53,
#    244.71,
#    419.02,
#    246.91,
#    419.53,
#    248.31,
#    420.73,
#    250.21,
#    422.22,
#    251.9,
#    423.72,
#    253.2,
#    423.83,
#    255.01,
#    421.92,
#    255.5,
#    420.82,
#    254.4,
#    419.53,
#    252.61,
#    418.02,
#    250.41,
#    416.92,
#    248.11,
#    416.03,
#    245.71,
#    416.03,
#    245.71,
#    415.13,
#    243.61,
#    412.73,
#    242.81,
#    411.32,
#    241.9,
#    409.43,
#    240.81,
#    408.92,
#    243.71,
#    408.82,
#    245.61,
#    408.12,
#    248.01,
#    408.22,
#    249.8,
#    407.72,
#    252.91,
#    408.72,
#    254.91,
#    409.32,
#    256.01,
#    405.82,
#    255.61,
#    405.72,
#    253.71,
#    405.32,
#    251.81,
#    405.62,
#    249.71,
#    405.92,
#    246.4,
#    406.13,
#    243.61,
#    405.62,
#    241.0,
#    404.93,
#    236.91,
#    400.63,
#    236.91,
#    397.43,
#    236.01,
#    396.33,
#    234.61,
#    393.93,
#    231.81,
#    393.72,
#    236.11,
#    393.12,
#    238.41,
#    393.22,
#    240.51,
#    393.62,
#    242.81,
#    394.32,
#    245.4,
#    395.03,
#    247.21,
#    395.92,
#    249.71,
#    396.92,
#    251.81,
#    396.42,
#    253.51,
#    394.82,
#    253.3,
#    393.83,
#    252.41,
#    392.93,
#    250.31,
#    392.62,
#    247.6,
#    391.63,
#    245.21,
#    391.12,
#    243.61,
#    389.53,
#    243.3,
#    389.22,
#    241.71,
#    390.12,
#    240.41,
#    390.63,
#    239.8,
#    390.63,
#    235.81,
#    389.32,
#    233.81,
#    388.02,
#    231.71,
#    387.33,
#    229.31,
#    386.52,
#    226.91,
#    385.42,
#    225.81,
#    385.92,
#    223.2,
#    385.92,
#    220.21,
#    385.62,
#    217.91,
#    384.72,
#    215.5,
#    386.52,
#    213.51,
#    389.73,
#    212.81,
#    393.83,
#    211.61,
#    398.72,
#    211.41,
#    403.83,
#    212.71,
#    408.33,
#    214.4,
#    412.12,
#    216.81,
#    416.82,
#    220.11,
#    420.92,
#    223.01,
#    423.42,
#    227.91,
#    427.42,
#    232.31,
#    430.02,
#    235.01,
#    430.92,
#    237.41]],
#  'area': 1205.0,
#  'bbox': [384.72, 211.41, 51.15, 44.6],
#  'iscrowd': 0,
#  'attributes': {'occluded': False, 'track_id': 0, 'keyframe': True}}

# %%
data_images[0]
# Out:
# {'id': '20200807023726-31',
#  'width': 848,
#  'height': 480,
#  'file_name': '20200807023726/color/000031.jpg',
#  'license': 0,
#  'flickr_url': '',
#  'coco_url': '',
#  'date_captured': 0,
#  'seq_id': '20200807023726',
#  'seq_num_frames': 451,
#  'frame_num': 31,
#  'corrupt': False,
#  'location': 0,
#  'datetime': '2020-08-07 02:37:26'}

# %%
data_categories
# Out:
# [{'id': 1, 'name': 'deer', 'supercategory': ''},
#  {'id': 2, 'name': 'goat', 'supercategory': ''},
#  {'id': 3, 'name': 'donkey', 'supercategory': ''},
#  {'id': 4, 'name': 'goose', 'supercategory': ''}]

# %% [markdown]
# ## Define Functions

# %%
def bbox_coco2yolo(coco_bbox: Tuple[float, float, float, float], img_dims: Tuple[float, float], epsilon=1) -> Tuple[float, float, float, float]:
    '''
    Converts a COCO JSON bbox into a YOLOv5 bbox.

    Inputs:
        coco_bbox: A tuple of form (x_tl, y_tl, w, h), where...
          - x_tl is the top-left x-coordinate
          - y_tl is the top-left y-coordinate
          - w is the width of the bbox
          - h is the height of the bbox
        img_dims: A tuple of form (W, H), where...
          - W is the width of the image
          - H is the height of the image
        epsilon: A small stabilization term that represents the number of pixels (horizontal and vertical) with which x_c and y_c are moved to prevent
                 bounding boxes from having coordinates outside the normalized range [0, 1] because of floating point instability.

    Returns:
        A YOLOv5-formatted bbox of form (x_c, y_c, w, h), where...
          - x_c is the (normalized) center x-coordinate
          - y_c is the (normalized) center y-coordinate
          - w is the (normalized) width of the bbox
          - h is the (normalized) height of the bbox
    '''
    
    # unpack arguments
    x_tl, y_tl, w, h = coco_bbox
    W, H = img_dims

    # compute bbox center coordinates
    x_br = x_tl + w
    y_br = y_tl + h

    x_c = (x_tl + x_br) / 2
    y_c = (y_tl + y_br) / 2

    # move bbox towards center using epsilon (for stability)
    W_mid = W / 2
    H_mid = H / 2

    dx_c = -1 if x_c > W_mid else 1 if x_c < W_mid else 0
    dy_c = -1 if y_c > H_mid else 1 if y_c < H_mid else 0

    x_c += dx_c * epsilon
    y_c += dy_c * epsilon

    # normalize
    x_c /= W
    y_c /= H

    w /= W
    h /= H

    # round coordinates
    x_c = round(x_c, 4)
    y_c = round(y_c, 4)

    w = round(w, 4)
    h = round(h, 4)

    # return YOLOv5 bbox coordinates
    return x_c, y_c, w, h

# %%
def find_img(images: List[Dict], target_id: str, debug=False) -> Dict:
    '''
    Given a target image ID, finds and returns the appropriate image.

    Inputs:
        images: A list of image objects, as obtained from the COCO JSON file.
        target_id: A string representing the target image ID to be returned.
        debug: A boolean flag which puts the function into debug mode (adds extra print statements) when True.

    Returns:
        img: the image associated with the entered target image ID (if one exists). If none exists, throws a ValueError.
    '''

    for img in images:
        img_id = img['id']

        if img_id == target_id:
            if debug:
                print(f'Found image with ID "{target_id}"!')

            return img

    raise ValueError(f'Error: No image with ID "{target_id}" found!')

# %%
def convert_annotations(images: List[Dict], annotations: List[Dict], debug=False) -> Dict[str, List[str]]:
    '''
    Converts all COCO JSON annotations into YOLOv5 annotations

    Inputs:
        images: A list of image objects, as obtained from the COCO JSON file.
        annotations: A list of annotation objects, as obtained from a COCO JSON file.
        debug: A boolean flag which puts the function into debug mode (adds extra print statements) when True.
    
    Returns:
        yolo_annotations: A dictionary containing all converted YOLOv5 annotations, with image filenames used as the keys.
    '''
    
    yolo_annotations = dict()

    for annotation in tqdm.tqdm(annotations):
        # unpack necessary annotation data
        annotation_id = annotation['id']
        target_id = annotation['image_id']
        category_id = annotation['category_id']
        coco_bbox = annotation['bbox']

        # find and unpack necessary image data
        try:
            img = find_img(images, target_id, debug=debug)
            img_dims = (img['width'], img['height'])
            img_name = img['file_name']

            # create and store YOLOv5 annotation
            x_c, y_c, w, h = bbox_coco2yolo(coco_bbox, img_dims)
            yolo_annotation = f'{category_id - 1} {x_c} {y_c} {w} {h}'

            if img_name in list(yolo_annotations.keys()):
                yolo_annotations[img_name].append(yolo_annotation)
            else:
                yolo_annotations[img_name] = [yolo_annotation]

            if debug:
                print(f'Converted and stored annotation with ID "{annotation_id}" as a YOLOv5 annotation!')
        except ValueError:
            if debug:
                print(f'Couldn\'t find image with ID "{target_id}"... skipping.')

    return yolo_annotations

# %%
def generate_empty_annotations(images: List[Dict], annotations: List[Dict], debug=False) -> Dict[str, List]:
    '''
    Converts all empty images into (empty) YOLOv5 annotations.

    Inputs:
        images: A list of image objects, as obtained from the COCO JSON file.
        annotations: A list of annotation objects, as obtained from a COCO JSON file.
        debug: A boolean flag which puts the function into debug mode (adds extra print statements) when True.

    Returns:
        empty_annotations: A dictionary containing all empty YOLOv5 annotations, with image filenames used as the keys.
    '''

    # get all annotated image IDs
    annotations_set = set()

    for annotation in annotations:
        img_id = annotation['image_id']
        annotations_set.add(img_id)

    if debug:
        print(f'{len(annotations_set)} Annotated Images.')

    # get all image IDs (annotated and unannotated)
    images_set = set()

    for img in images:
        img_id = img['id']
        images_set.add(img_id)

    if debug:
        print(f'{len(images_set)} Images.')

    # find difference between the sets to get empty images
    empties_set = images_set - annotations_set
    if debug:
        print(f'{len(empties_set)} Empty Images.')

    # store and return empty annotations
    empty_annotations = dict()

    for img in images:
        img_id = img['id']
        img_name = img['file_name']
        
        if img_id in empties_set:
            empty_annotations[img_name] = []

    return empty_annotations

# %%
def write_annotations(yolo_annotations: Dict[str, List[str]], empty_annotations: Dict[str, List], src_imgs: str, dest_imgs: str, dest_labels: str, debug=False) -> None:
    '''
    Builds a YOLOv5-formatted dataset in the destination folders.

    Inputs:
        yolo_annotations: a dictionary of generated YOLOv5 annotations, as returned by the "convert_annotations" function.
        empty_annotations: a dictionary of generated (empty) YOLOv5 annotations, as returned by the "generate_empty_annotations" function.
        src_imgs: the source images folder (from the COCO dataset).
        dest_imgs: the destination images folder (in the new YOLOv5 dataset).
        dest_labels: the destination annotations folder (in the new YOLOv5 dataset).
        debug: A boolean flag which puts the function into debug mode (adds extra print statements) when True.
    
    Returns: Nothing :)
    '''

    all_annotations = dict()
    all_annotations.update(yolo_annotations)
    all_annotations.update(empty_annotations)

    for img_name, annotations_list in all_annotations.items():
        # extract necessary information
        filename = img_name.split('/')[-1]
        basename = '.'.join(filename.split('.')[:-1])
        extension  = filename.split('.')[-1]

        # if collision with existing file, then rename to avoid overwriting
        count = 0

        prop_full_dest_img_path = dest_imgs + basename + f'-{count}.' + extension
        prop_full_dest_labels_path = dest_labels + basename + f'-{count}.txt'

        while os.path.exists(prop_full_dest_img_path) or os.path.exists(prop_full_dest_labels_path):
            count += 1
            
            prop_full_dest_img_path = dest_imgs + basename + f'-{count}.' + extension
            prop_full_dest_labels_path = dest_labels + basename + f'-{count}.txt'

        full_src_img_path = src_imgs + img_name
        full_dest_img_path = prop_full_dest_img_path
        full_dest_labels_path = prop_full_dest_labels_path

        del prop_full_dest_img_path
        del prop_full_dest_labels_path

        # copy images to destination images folder, and write annotations in destionation labels folder
        shutil.copy(full_src_img_path, full_dest_img_path)
        with open(full_dest_labels_path, 'a') as f:
            for annotations_str in annotations_list:
                f.write(annotations_str + '\n')

            if len(annotations_str) == 0:
                f.write('')

        if debug:
            print(f'Successfully wrote all annotations for image "{img_name}"!')

# %%
def write_labelmap(categories: List[Dict], dest: str, debug=False) -> None:
    '''
    Writes a labelmap.txt in the root of the YOLOv5 dataset (if it doesn't exist already).

    Inputs:
        categories: a dictionary containing all the possible classes and their respective natural language names.
        dest: the root of the destination YOLOv5 dataset.
        debug: A boolean flag which puts the function into debug mode (adds extra print statements) when True.
    
    Returns: Nothing :)
    '''
    
    filename = 'labelmap.txt'
    full_filepath = dest + filename

    if not os.path.exists(full_filepath):
        with open(full_filepath, 'a') as f:
            for category in categories:
                f.write(f'{category["name"]}\n')

        if debug:
            print('labelmap.txt written in root of dataset!')
    else:
        if debug:
            print('labelmap.txt already exists!')

# %% [markdown]
# ## Use Functions to Generate a YOLOv5 Dataset from our Parameters.
#
# Please run the cells below when you want to generate your YOLOv5 dataset using your previously-defined parameters.

# %%
debug = True

# %%
yolo_annotations = convert_annotations(data_images, data_annotations, debug=debug)
empty_annotations = generate_empty_annotations(data_images, data_annotations, debug=debug)
# Out:
# 100%|██████████| 976/976 [00:00<00:00, 33173.21it/s]
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "458" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "459" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "460" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "461" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "462" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "463" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "464" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "465" as a YOLOv5 annotation!
# Found image with ID "20200807023726-31"!
# Converted and stored annotation with ID "466" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "548" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "549" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "550" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "551" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "552" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "553" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "554" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "555" as a YOLOv5 annotation!
# Found image with ID "20200807023726-41"!
# Converted and stored annotation with ID "556" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "638" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "639" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "640" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "641" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "642" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "643" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "644" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "645" as a YOLOv5 annotation!
# Found image with ID "20200807023726-51"!
# Converted and stored annotation with ID "646" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "728" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "729" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "730" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "731" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "732" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "733" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "734" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "735" as a YOLOv5 annotation!
# Found image with ID "20200807023726-61"!
# Converted and stored annotation with ID "736" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "812" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "813" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "814" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "815" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "816" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "817" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "818" as a YOLOv5 annotation!
# Found image with ID "20200807023726-71"!
# Converted and stored annotation with ID "819" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "892" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "893" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "894" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "895" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "896" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "897" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "898" as a YOLOv5 annotation!
# Found image with ID "20200807023726-81"!
# Converted and stored annotation with ID "899" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "966" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "967" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "968" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "969" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "970" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "971" as a YOLOv5 annotation!
# Found image with ID "20200807023726-91"!
# Converted and stored annotation with ID "972" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1036" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1037" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1038" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1039" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1040" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1041" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1042" as a YOLOv5 annotation!
# Found image with ID "20200807023726-101"!
# Converted and stored annotation with ID "1043" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1116" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1117" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1118" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1119" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1120" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1121" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1122" as a YOLOv5 annotation!
# Found image with ID "20200807023726-111"!
# Converted and stored annotation with ID "1123" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1196" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1197" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1198" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1199" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1200" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1201" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1202" as a YOLOv5 annotation!
# Found image with ID "20200807023726-121"!
# Converted and stored annotation with ID "1203" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1276" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1277" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1278" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1279" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1280" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1281" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1282" as a YOLOv5 annotation!
# Found image with ID "20200807023726-131"!
# Converted and stored annotation with ID "1283" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1354" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1355" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1356" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1357" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1358" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1359" as a YOLOv5 annotation!
# Found image with ID "20200807023726-141"!
# Converted and stored annotation with ID "1360" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1424" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1425" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1426" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1427" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1428" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1429" as a YOLOv5 annotation!
# Found image with ID "20200807023726-151"!
# Converted and stored annotation with ID "1430" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1494" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1495" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1496" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1497" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1498" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1499" as a YOLOv5 annotation!
# Found image with ID "20200807023726-161"!
# Converted and stored annotation with ID "1500" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1564" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1565" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1566" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1567" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1568" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1569" as a YOLOv5 annotation!
# Found image with ID "20200807023726-171"!
# Converted and stored annotation with ID "1570" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1634" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1635" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1636" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1637" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1638" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1639" as a YOLOv5 annotation!
# Found image with ID "20200807023726-181"!
# Converted and stored annotation with ID "1640" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1704" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1705" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1706" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1707" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1708" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1709" as a YOLOv5 annotation!
# Found image with ID "20200807023726-191"!
# Converted and stored annotation with ID "1710" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1774" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1775" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1776" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1777" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1778" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1779" as a YOLOv5 annotation!
# Found image with ID "20200807023726-201"!
# Converted and stored annotation with ID "1780" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1844" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1845" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1846" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1847" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1848" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1849" as a YOLOv5 annotation!
# Found image with ID "20200807023726-211"!
# Converted and stored annotation with ID "1850" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1914" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1915" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1916" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1917" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1918" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1919" as a YOLOv5 annotation!
# Found image with ID "20200807023726-221"!
# Converted and stored annotation with ID "1920" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1984" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1985" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1986" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1987" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1988" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1989" as a YOLOv5 annotation!
# Found image with ID "20200807023726-231"!
# Converted and stored annotation with ID "1990" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2046" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2047" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2048" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2049" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2050" as a YOLOv5 annotation!
# Found image with ID "20200807023726-241"!
# Converted and stored annotation with ID "2051" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2106" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2107" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2108" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2109" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2110" as a YOLOv5 annotation!
# Found image with ID "20200807023726-251"!
# Converted and stored annotation with ID "2111" as a YOLOv5 annotation!
# Found image with ID "20200807023726-261"!
# Converted and stored annotation with ID "2159" as a YOLOv5 annotation!
# Found image with ID "20200807023726-261"!
# Converted and stored annotation with ID "2160" as a YOLOv5 annotation!
# Found image with ID "20200807023726-261"!
# Converted and stored annotation with ID "2161" as a YOLOv5 annotation!
# Found image with ID "20200807023726-261"!
# Converted and stored annotation with ID "2162" as a YOLOv5 annotation!
# Found image with ID "20200807023726-261"!
# Converted and stored annotation with ID "2163" as a YOLOv5 annotation!
# Found image with ID "20200807023726-271"!
# Converted and stored annotation with ID "2209" as a YOLOv5 annotation!
# Found image with ID "20200807023726-271"!
# Converted and stored annotation with ID "2210" as a YOLOv5 annotation!
# Found image with ID "20200807023726-271"!
# Converted and stored annotation with ID "2211" as a YOLOv5 annotation!
# Found image with ID "20200807023726-271"!
# Converted and stored annotation with ID "2212" as a YOLOv5 annotation!
# Found image with ID "20200807023726-271"!
# Converted and stored annotation with ID "2213" as a YOLOv5 annotation!
# Found image with ID "20200807023726-281"!
# Converted and stored annotation with ID "2259" as a YOLOv5 annotation!
# Found image with ID "20200807023726-281"!
# Converted and stored annotation with ID "2260" as a YOLOv5 annotation!
# Found image with ID "20200807023726-281"!
# Converted and stored annotation with ID "2261" as a YOLOv5 annotation!
# Found image with ID "20200807023726-281"!
# Converted and stored annotation with ID "2262" as a YOLOv5 annotation!
# Found image with ID "20200807023726-281"!
# Converted and stored annotation with ID "2263" as a YOLOv5 annotation!
# Found image with ID "20200807023726-291"!
# Converted and stored annotation with ID "2309" as a YOLOv5 annotation!
# Found image with ID "20200807023726-291"!
# Converted and stored annotation with ID "2310" as a YOLOv5 annotation!
# Found image with ID "20200807023726-291"!
# Converted and stored annotation with ID "2311" as a YOLOv5 annotation!
# Found image with ID "20200807023726-291"!
# Converted and stored annotation with ID "2312" as a YOLOv5 annotation!
# Found image with ID "20200807023726-291"!
# Converted and stored annotation with ID "2313" as a YOLOv5 annotation!
# Found image with ID "20200807023726-301"!
# Converted and stored annotation with ID "2357" as a YOLOv5 annotation!
# Found image with ID "20200807023726-301"!
# Converted and stored annotation with ID "2358" as a YOLOv5 annotation!
# Found image with ID "20200807023726-301"!
# Converted and stored annotation with ID "2359" as a YOLOv5 annotation!
# Found image with ID "20200807023726-301"!
# Converted and stored annotation with ID "2360" as a YOLOv5 annotation!
# Found image with ID "20200807023726-311"!
# Converted and stored annotation with ID "2397" as a YOLOv5 annotation!
# Found image with ID "20200807023726-311"!
# Converted and stored annotation with ID "2398" as a YOLOv5 annotation!
# Found image with ID "20200807023726-311"!
# Converted and stored annotation with ID "2399" as a YOLOv5 annotation!
# Found image with ID "20200807023726-311"!
# Converted and stored annotation with ID "2400" as a YOLOv5 annotation!
# Found image with ID "20200807023726-321"!
# Converted and stored annotation with ID "2437" as a YOLOv5 annotation!
# Found image with ID "20200807023726-321"!
# Converted and stored annotation with ID "2438" as a YOLOv5 annotation!
# Found image with ID "20200807023726-321"!
# Converted and stored annotation with ID "2439" as a YOLOv5 annotation!
# Found image with ID "20200807023726-321"!
# Converted and stored annotation with ID "2440" as a YOLOv5 annotation!
# Found image with ID "20200807023726-331"!
# Converted and stored annotation with ID "2477" as a YOLOv5 annotation!
# Found image with ID "20200807023726-331"!
# Converted and stored annotation with ID "2478" as a YOLOv5 annotation!
# Found image with ID "20200807023726-331"!
# Converted and stored annotation with ID "2479" as a YOLOv5 annotation!
# Found image with ID "20200807023726-331"!
# Converted and stored annotation with ID "2480" as a YOLOv5 annotation!
# Found image with ID "20200807023726-341"!
# Converted and stored annotation with ID "2517" as a YOLOv5 annotation!
# Found image with ID "20200807023726-341"!
# Converted and stored annotation with ID "2518" as a YOLOv5 annotation!
# Found image with ID "20200807023726-341"!
# Converted and stored annotation with ID "2519" as a YOLOv5 annotation!
# Found image with ID "20200807023726-341"!
# Converted and stored annotation with ID "2520" as a YOLOv5 annotation!
# Found image with ID "20200807023726-351"!
# Converted and stored annotation with ID "2557" as a YOLOv5 annotation!
# Found image with ID "20200807023726-351"!
# Converted and stored annotation with ID "2558" as a YOLOv5 annotation!
# Found image with ID "20200807023726-351"!
# Converted and stored annotation with ID "2559" as a YOLOv5 annotation!
# Found image with ID "20200807023726-351"!
# Converted and stored annotation with ID "2560" as a YOLOv5 annotation!
# Found image with ID "20200807023726-361"!
# Converted and stored annotation with ID "2597" as a YOLOv5 annotation!
# Found image with ID "20200807023726-361"!
# Converted and stored annotation with ID "2598" as a YOLOv5 annotation!
# Found image with ID "20200807023726-361"!
# Converted and stored annotation with ID "2599" as a YOLOv5 annotation!
# Found image with ID "20200807023726-361"!
# Converted and stored annotation with ID "2600" as a YOLOv5 annotation!
# Found image with ID "20200807023726-371"!
# Converted and stored annotation with ID "2637" as a YOLOv5 annotation!
# Found image with ID "20200807023726-371"!
# Converted and stored annotation with ID "2638" as a YOLOv5 annotation!
# Found image with ID "20200807023726-371"!
# Converted and stored annotation with ID "2639" as a YOLOv5 annotation!
# Found image with ID "20200807023726-371"!
# Converted and stored annotation with ID "2640" as a YOLOv5 annotation!
# Found image with ID "20200807023726-381"!
# Converted and stored annotation with ID "2677" as a YOLOv5 annotation!
# Found image with ID "20200807023726-381"!
# Converted and stored annotation with ID "2678" as a YOLOv5 annotation!
# Found image with ID "20200807023726-381"!
# Converted and stored annotation with ID "2679" as a YOLOv5 annotation!
# Found image with ID "20200807023726-381"!
# Converted and stored annotation with ID "2680" as a YOLOv5 annotation!
# Found image with ID "20200807023726-391"!
# Converted and stored annotation with ID "2717" as a YOLOv5 annotation!
# Found image with ID "20200807023726-391"!
# Converted and stored annotation with ID "2718" as a YOLOv5 annotation!
# Found image with ID "20200807023726-391"!
# Converted and stored annotation with ID "2719" as a YOLOv5 annotation!
# Found image with ID "20200807023726-391"!
# Converted and stored annotation with ID "2720" as a YOLOv5 annotation!
# Found image with ID "20200807023726-401"!
# Converted and stored annotation with ID "2757" as a YOLOv5 annotation!
# Found image with ID "20200807023726-401"!
# Converted and stored annotation with ID "2758" as a YOLOv5 annotation!
# Found image with ID "20200807023726-401"!
# Converted and stored annotation with ID "2759" as a YOLOv5 annotation!
# Found image with ID "20200807023726-401"!
# Converted and stored annotation with ID "2760" as a YOLOv5 annotation!
# Found image with ID "20200807023726-411"!
# Converted and stored annotation with ID "2797" as a YOLOv5 annotation!
# Found image with ID "20200807023726-411"!
# Converted and stored annotation with ID "2798" as a YOLOv5 annotation!
# Found image with ID "20200807023726-411"!
# Converted and stored annotation with ID "2799" as a YOLOv5 annotation!
# Found image with ID "20200807023726-411"!
# Converted and stored annotation with ID "2800" as a YOLOv5 annotation!
# Found image with ID "20200807023726-421"!
# Converted and stored annotation with ID "2837" as a YOLOv5 annotation!
# Found image with ID "20200807023726-421"!
# Converted and stored annotation with ID "2838" as a YOLOv5 annotation!
# Found image with ID "20200807023726-421"!
# Converted and stored annotation with ID "2839" as a YOLOv5 annotation!
# Found image with ID "20200807023726-421"!
# Converted and stored annotation with ID "2840" as a YOLOv5 annotation!
# Found image with ID "20200807023726-431"!
# Converted and stored annotation with ID "2877" as a YOLOv5 annotation!
# Found image with ID "20200807023726-431"!
# Converted and stored annotation with ID "2878" as a YOLOv5 annotation!
# Found image with ID "20200807023726-431"!
# Converted and stored annotation with ID "2879" as a YOLOv5 annotation!
# Found image with ID "20200807023726-431"!
# Converted and stored annotation with ID "2880" as a YOLOv5 annotation!
# Found image with ID "20200807023726-441"!
# Converted and stored annotation with ID "2917" as a YOLOv5 annotation!
# Found image with ID "20200807023726-441"!
# Converted and stored annotation with ID "2918" as a YOLOv5 annotation!
# Found image with ID "20200807023726-441"!
# Converted and stored annotation with ID "2919" as a YOLOv5 annotation!
# Found image with ID "20200807023726-441"!
# Converted and stored annotation with ID "2920" as a YOLOv5 annotation!
# Found image with ID "20200807023726-451"!
# Converted and stored annotation with ID "2957" as a YOLOv5 annotation!
# Found image with ID "20200807023726-451"!
# Converted and stored annotation with ID "2958" as a YOLOv5 annotation!
# Found image with ID "20200807023726-451"!
# Converted and stored annotation with ID "2959" as a YOLOv5 annotation!
# Found image with ID "20200807023726-451"!
# Converted and stored annotation with ID "2960" as a YOLOv5 annotation!
# Found image with ID "20200807031150-21"!
# Converted and stored annotation with ID "2961" as a YOLOv5 annotation!
# Found image with ID "20200807031150-21"!
# Converted and stored annotation with ID "2962" as a YOLOv5 annotation!
# Found image with ID "20200807031150-31"!
# Converted and stored annotation with ID "2981" as a YOLOv5 annotation!
# Found image with ID "20200807031150-31"!
# Converted and stored annotation with ID "2982" as a YOLOv5 annotation!
# Found image with ID "20200807031150-41"!
# Converted and stored annotation with ID "2999" as a YOLOv5 annotation!
# Found image with ID "20200807031150-51"!
# Converted and stored annotation with ID "3009" as a YOLOv5 annotation!
# Found image with ID "20200807031150-61"!
# Converted and stored annotation with ID "3019" as a YOLOv5 annotation!
# Found image with ID "20200807031150-71"!
# Converted and stored annotation with ID "3029" as a YOLOv5 annotation!
# Found image with ID "20200807031150-81"!
# Converted and stored annotation with ID "3039" as a YOLOv5 annotation!
# Found image with ID "20200807031150-91"!
# Converted and stored annotation with ID "3049" as a YOLOv5 annotation!
# Found image with ID "20200807031150-101"!
# Converted and stored annotation with ID "3059" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3062" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3063" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3064" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3065" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3066" as a YOLOv5 annotation!
# Found image with ID "20200807061001-31"!
# Converted and stored annotation with ID "3067" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3122" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3123" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3124" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3125" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3126" as a YOLOv5 annotation!
# Found image with ID "20200807061001-41"!
# Converted and stored annotation with ID "3127" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3182" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3183" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3184" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3185" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3186" as a YOLOv5 annotation!
# Found image with ID "20200807061001-51"!
# Converted and stored annotation with ID "3187" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3242" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3243" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3244" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3245" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3246" as a YOLOv5 annotation!
# Found image with ID "20200807061001-61"!
# Converted and stored annotation with ID "3247" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3302" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3303" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3304" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3305" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3306" as a YOLOv5 annotation!
# Found image with ID "20200807061001-71"!
# Converted and stored annotation with ID "3307" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3362" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3363" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3364" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3365" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3366" as a YOLOv5 annotation!
# Found image with ID "20200807061001-81"!
# Converted and stored annotation with ID "3367" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3422" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3423" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3424" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3425" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3426" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3427" as a YOLOv5 annotation!
# Found image with ID "20200807061001-91"!
# Converted and stored annotation with ID "3428" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3483" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3484" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3485" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3486" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3487" as a YOLOv5 annotation!
# Found image with ID "20200807061001-101"!
# Converted and stored annotation with ID "3488" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3543" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3544" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3545" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3546" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3547" as a YOLOv5 annotation!
# Found image with ID "20200807061001-111"!
# Converted and stored annotation with ID "3548" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3603" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3604" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3605" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3606" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3607" as a YOLOv5 annotation!
# Found image with ID "20200807061001-121"!
# Converted and stored annotation with ID "3608" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3663" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3664" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3665" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3666" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3667" as a YOLOv5 annotation!
# Found image with ID "20200807061001-131"!
# Converted and stored annotation with ID "3668" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3723" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3724" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3725" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3726" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3727" as a YOLOv5 annotation!
# Found image with ID "20200807061001-141"!
# Converted and stored annotation with ID "3728" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3783" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3784" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3785" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3786" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3787" as a YOLOv5 annotation!
# Found image with ID "20200807061001-151"!
# Converted and stored annotation with ID "3788" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3843" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3844" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3845" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3846" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3847" as a YOLOv5 annotation!
# Found image with ID "20200807061001-161"!
# Converted and stored annotation with ID "3848" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3903" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3904" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3905" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3906" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3907" as a YOLOv5 annotation!
# Found image with ID "20200807061001-171"!
# Converted and stored annotation with ID "3908" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3963" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3964" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3965" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3966" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3967" as a YOLOv5 annotation!
# Found image with ID "20200807061001-181"!
# Converted and stored annotation with ID "3968" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4023" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4024" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4025" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4026" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4027" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4028" as a YOLOv5 annotation!
# Found image with ID "20200807061001-191"!
# Converted and stored annotation with ID "4029" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4084" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4085" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4086" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4087" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4088" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4089" as a YOLOv5 annotation!
# Found image with ID "20200807061001-201"!
# Converted and stored annotation with ID "4090" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4145" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4146" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4147" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4148" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4149" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4150" as a YOLOv5 annotation!
# Found image with ID "20200807061001-211"!
# Converted and stored annotation with ID "4151" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4206" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4207" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4208" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4209" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4210" as a YOLOv5 annotation!
# Found image with ID "20200807061001-221"!
# Converted and stored annotation with ID "4211" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4266" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4267" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4268" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4269" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4270" as a YOLOv5 annotation!
# Found image with ID "20200807061001-231"!
# Converted and stored annotation with ID "4271" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4326" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4327" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4328" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4329" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4330" as a YOLOv5 annotation!
# Found image with ID "20200807061001-241"!
# Converted and stored annotation with ID "4331" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4386" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4387" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4388" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4389" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4390" as a YOLOv5 annotation!
# Found image with ID "20200807061001-251"!
# Converted and stored annotation with ID "4391" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4446" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4447" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4448" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4449" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4450" as a YOLOv5 annotation!
# Found image with ID "20200807061001-261"!
# Converted and stored annotation with ID "4451" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4506" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4507" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4508" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4509" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4510" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4511" as a YOLOv5 annotation!
# Found image with ID "20200807061001-271"!
# Converted and stored annotation with ID "4512" as a YOLOv5 annotation!
# Found image with ID "20200807061001-281"!
# Converted and stored annotation with ID "4567" as a YOLOv5 annotation!
# Found image with ID "20200807061001-281"!
# Converted and stored annotation with ID "4568" as a YOLOv5 annotation!
# Found image with ID "20200807061001-281"!
# ...
# Found image with ID "20200930211737-261"!
# Converted and stored annotation with ID "6496" as a YOLOv5 annotation!
# Found image with ID "20200930211737-271"!
# Converted and stored annotation with ID "6497" as a YOLOv5 annotation!
# Found image with ID "20200930211737-281"!
# Converted and stored annotation with ID "6498" as a YOLOv5 annotation!
# Found image with ID "20200930211737-291"!
# Converted and stored annotation with ID "6499" as a YOLOv5 annotation!
# Found image with ID "20200930211737-301"!
# Converted and stored annotation with ID "6500" as a YOLOv5 annotation!
# Found image with ID "20200930211737-311"!
# Converted and stored annotation with ID "6501" as a YOLOv5 annotation!
# Found image with ID "20200930211737-321"!
# Converted and stored annotation with ID "6502" as a YOLOv5 annotation!
# Found image with ID "20200930211737-331"!
# Converted and stored annotation with ID "6503" as a YOLOv5 annotation!
# Found image with ID "20200930211737-341"!
# Converted and stored annotation with ID "6504" as a YOLOv5 annotation!
# Found image with ID "20200930211737-351"!
# Converted and stored annotation with ID "6505" as a YOLOv5 annotation!
# Found image with ID "20200930211737-361"!
# Converted and stored annotation with ID "6506" as a YOLOv5 annotation!
# Found image with ID "20200930211737-371"!
# Converted and stored annotation with ID "6507" as a YOLOv5 annotation!
# Found image with ID "20200930211737-381"!
# Converted and stored annotation with ID "6508" as a YOLOv5 annotation!
# Found image with ID "20200930211737-391"!
# Converted and stored annotation with ID "6509" as a YOLOv5 annotation!
# Found image with ID "20200930211737-401"!
# Converted and stored annotation with ID "6510" as a YOLOv5 annotation!
# Found image with ID "20200930211737-411"!
# Converted and stored annotation with ID "6511" as a YOLOv5 annotation!
# Found image with ID "20200930211737-421"!
# Converted and stored annotation with ID "6512" as a YOLOv5 annotation!
# Found image with ID "20200930211737-431"!
# Converted and stored annotation with ID "6513" as a YOLOv5 annotation!
# Found image with ID "20201001012942-31"!
# Converted and stored annotation with ID "6514" as a YOLOv5 annotation!
# Found image with ID "20201001012942-31"!
# Converted and stored annotation with ID "6515" as a YOLOv5 annotation!
# Found image with ID "20201001012942-41"!
# Converted and stored annotation with ID "6516" as a YOLOv5 annotation!
# Found image with ID "20201001012942-41"!
# Converted and stored annotation with ID "6517" as a YOLOv5 annotation!
# Found image with ID "20201001012942-51"!
# Converted and stored annotation with ID "6518" as a YOLOv5 annotation!
# Found image with ID "20201001012942-51"!
# Converted and stored annotation with ID "6519" as a YOLOv5 annotation!
# Found image with ID "20201001012942-61"!
# Converted and stored annotation with ID "6520" as a YOLOv5 annotation!
# Found image with ID "20201001012942-61"!
# Converted and stored annotation with ID "6521" as a YOLOv5 annotation!
# Found image with ID "20201001012942-71"!
# Converted and stored annotation with ID "6522" as a YOLOv5 annotation!
# Found image with ID "20201001012942-71"!
# Converted and stored annotation with ID "6523" as a YOLOv5 annotation!
# Found image with ID "20201001012942-81"!
# Converted and stored annotation with ID "6524" as a YOLOv5 annotation!
# Found image with ID "20201001012942-81"!
# Converted and stored annotation with ID "6525" as a YOLOv5 annotation!
# Found image with ID "20201001012942-91"!
# Converted and stored annotation with ID "6526" as a YOLOv5 annotation!
# Found image with ID "20201001012942-91"!
# Converted and stored annotation with ID "6527" as a YOLOv5 annotation!
# Found image with ID "20201001012942-101"!
# Converted and stored annotation with ID "6528" as a YOLOv5 annotation!
# Found image with ID "20201001012942-101"!
# Converted and stored annotation with ID "6529" as a YOLOv5 annotation!
# Found image with ID "20201001012942-111"!
# Converted and stored annotation with ID "6530" as a YOLOv5 annotation!
# Found image with ID "20201001012942-111"!
# Converted and stored annotation with ID "6531" as a YOLOv5 annotation!
# Found image with ID "20201001012942-121"!
# Converted and stored annotation with ID "6532" as a YOLOv5 annotation!
# Found image with ID "20201001012942-121"!
# Converted and stored annotation with ID "6533" as a YOLOv5 annotation!
# Found image with ID "20201001012942-131"!
# Converted and stored annotation with ID "6534" as a YOLOv5 annotation!
# Found image with ID "20201001012942-131"!
# Converted and stored annotation with ID "6535" as a YOLOv5 annotation!
# Found image with ID "20201001012942-141"!
# Converted and stored annotation with ID "6536" as a YOLOv5 annotation!
# Found image with ID "20201001012942-141"!
# Converted and stored annotation with ID "6537" as a YOLOv5 annotation!
# Found image with ID "20201001012942-151"!
# Converted and stored annotation with ID "6538" as a YOLOv5 annotation!
# Found image with ID "20201001012942-151"!
# Converted and stored annotation with ID "6539" as a YOLOv5 annotation!
# Found image with ID "20201001012942-161"!
# Converted and stored annotation with ID "6540" as a YOLOv5 annotation!
# Found image with ID "20201001012942-161"!
# Converted and stored annotation with ID "6541" as a YOLOv5 annotation!
# Found image with ID "20201001012942-171"!
# Converted and stored annotation with ID "6542" as a YOLOv5 annotation!
# Found image with ID "20201001012942-171"!
# Converted and stored annotation with ID "6543" as a YOLOv5 annotation!
# Found image with ID "20201001012942-181"!
# Converted and stored annotation with ID "6544" as a YOLOv5 annotation!
# Found image with ID "20201001012942-181"!
# Converted and stored annotation with ID "6545" as a YOLOv5 annotation!
# Found image with ID "20201001012942-191"!
# Converted and stored annotation with ID "6546" as a YOLOv5 annotation!
# Found image with ID "20201001012942-191"!
# Converted and stored annotation with ID "6547" as a YOLOv5 annotation!
# Found image with ID "20201001012942-201"!
# Converted and stored annotation with ID "6548" as a YOLOv5 annotation!
# Found image with ID "20201001012942-201"!
# Converted and stored annotation with ID "6549" as a YOLOv5 annotation!
# Found image with ID "20201001012942-211"!
# Converted and stored annotation with ID "6550" as a YOLOv5 annotation!
# Found image with ID "20201001012942-211"!
# Converted and stored annotation with ID "6551" as a YOLOv5 annotation!
# Found image with ID "20201001012942-221"!
# Converted and stored annotation with ID "6552" as a YOLOv5 annotation!
# Found image with ID "20201001012942-221"!
# Converted and stored annotation with ID "6553" as a YOLOv5 annotation!
# Found image with ID "20201001012942-231"!
# Converted and stored annotation with ID "6554" as a YOLOv5 annotation!
# Found image with ID "20201001012942-231"!
# Converted and stored annotation with ID "6555" as a YOLOv5 annotation!
# Found image with ID "20201001012942-241"!
# Converted and stored annotation with ID "6556" as a YOLOv5 annotation!
# Found image with ID "20201001012942-241"!
# Converted and stored annotation with ID "6557" as a YOLOv5 annotation!
# Found image with ID "20201001012942-251"!
# Converted and stored annotation with ID "6558" as a YOLOv5 annotation!
# Found image with ID "20201001012942-251"!
# Converted and stored annotation with ID "6559" as a YOLOv5 annotation!
# Found image with ID "20201001012942-261"!
# Converted and stored annotation with ID "6560" as a YOLOv5 annotation!
# Found image with ID "20201001012942-261"!
# Converted and stored annotation with ID "6561" as a YOLOv5 annotation!
# Found image with ID "20201001012942-271"!
# Converted and stored annotation with ID "6562" as a YOLOv5 annotation!
# Found image with ID "20201001012942-271"!
# Converted and stored annotation with ID "6563" as a YOLOv5 annotation!
# Found image with ID "20201001012942-281"!
# Converted and stored annotation with ID "6564" as a YOLOv5 annotation!
# Found image with ID "20201001012942-281"!
# Converted and stored annotation with ID "6565" as a YOLOv5 annotation!
# Found image with ID "20201001012942-291"!
# Converted and stored annotation with ID "6566" as a YOLOv5 annotation!
# Found image with ID "20201001012942-291"!
# Converted and stored annotation with ID "6567" as a YOLOv5 annotation!
# Found image with ID "20201001012942-301"!
# Converted and stored annotation with ID "6568" as a YOLOv5 annotation!
# Found image with ID "20201001012942-301"!
# Converted and stored annotation with ID "6569" as a YOLOv5 annotation!
# Found image with ID "20201001012942-311"!
# Converted and stored annotation with ID "6570" as a YOLOv5 annotation!
# Found image with ID "20201001012942-311"!
# Converted and stored annotation with ID "6571" as a YOLOv5 annotation!
# Found image with ID "20201001012942-321"!
# Converted and stored annotation with ID "6572" as a YOLOv5 annotation!
# Found image with ID "20201001012942-321"!
# Converted and stored annotation with ID "6573" as a YOLOv5 annotation!
# Found image with ID "20201001012942-331"!
# Converted and stored annotation with ID "6574" as a YOLOv5 annotation!
# Found image with ID "20201001012942-331"!
# Converted and stored annotation with ID "6575" as a YOLOv5 annotation!
# Found image with ID "20201001012942-341"!
# Converted and stored annotation with ID "6576" as a YOLOv5 annotation!
# Found image with ID "20201001012942-341"!
# Converted and stored annotation with ID "6577" as a YOLOv5 annotation!
# Found image with ID "20201001012942-351"!
# Converted and stored annotation with ID "6578" as a YOLOv5 annotation!
# Found image with ID "20201001012942-351"!
# Converted and stored annotation with ID "6579" as a YOLOv5 annotation!
# Found image with ID "20201001012942-361"!
# Converted and stored annotation with ID "6580" as a YOLOv5 annotation!
# Found image with ID "20201001012942-361"!
# Converted and stored annotation with ID "6581" as a YOLOv5 annotation!
# Found image with ID "20201001012942-371"!
# Converted and stored annotation with ID "6582" as a YOLOv5 annotation!
# Found image with ID "20201001012942-371"!
# Converted and stored annotation with ID "6583" as a YOLOv5 annotation!
# Found image with ID "20201001012942-381"!
# Converted and stored annotation with ID "6584" as a YOLOv5 annotation!
# Found image with ID "20201001012942-381"!
# Converted and stored annotation with ID "6585" as a YOLOv5 annotation!
# Found image with ID "20201001012942-391"!
# Converted and stored annotation with ID "6586" as a YOLOv5 annotation!
# Found image with ID "20201001012942-391"!
# Converted and stored annotation with ID "6587" as a YOLOv5 annotation!
# Found image with ID "20201001012942-401"!
# Converted and stored annotation with ID "6588" as a YOLOv5 annotation!
# Found image with ID "20201001012942-401"!
# Converted and stored annotation with ID "6589" as a YOLOv5 annotation!
# Found image with ID "20201001012942-411"!
# Converted and stored annotation with ID "6590" as a YOLOv5 annotation!
# Found image with ID "20201001012942-411"!
# Converted and stored annotation with ID "6591" as a YOLOv5 annotation!
# Found image with ID "20201001012942-421"!
# Converted and stored annotation with ID "6592" as a YOLOv5 annotation!
# Found image with ID "20201001012942-421"!
# Converted and stored annotation with ID "6593" as a YOLOv5 annotation!
# Found image with ID "20201001012942-431"!
# Converted and stored annotation with ID "6594" as a YOLOv5 annotation!
# Found image with ID "20201001012942-431"!
# Converted and stored annotation with ID "6595" as a YOLOv5 annotation!
# Found image with ID "20201001202439-31"!
# Converted and stored annotation with ID "6596" as a YOLOv5 annotation!
# Found image with ID "20201001202439-41"!
# Converted and stored annotation with ID "6597" as a YOLOv5 annotation!
# Found image with ID "20201001202439-51"!
# Converted and stored annotation with ID "6598" as a YOLOv5 annotation!
# Found image with ID "20201001202439-61"!
# Converted and stored annotation with ID "6599" as a YOLOv5 annotation!
# Found image with ID "20201001202439-71"!
# Converted and stored annotation with ID "6600" as a YOLOv5 annotation!
# Found image with ID "20201001202439-81"!
# Converted and stored annotation with ID "6601" as a YOLOv5 annotation!
# Found image with ID "20201001202439-91"!
# Converted and stored annotation with ID "6602" as a YOLOv5 annotation!
# Found image with ID "20201001202439-101"!
# Converted and stored annotation with ID "6603" as a YOLOv5 annotation!
# Found image with ID "20201001202439-111"!
# Converted and stored annotation with ID "6604" as a YOLOv5 annotation!
# Found image with ID "20201001202439-121"!
# Converted and stored annotation with ID "6605" as a YOLOv5 annotation!
# Found image with ID "20201001202439-131"!
# Converted and stored annotation with ID "6606" as a YOLOv5 annotation!
# Found image with ID "20201001202439-141"!
# Converted and stored annotation with ID "6607" as a YOLOv5 annotation!
# Found image with ID "20201001202439-151"!
# Converted and stored annotation with ID "6608" as a YOLOv5 annotation!
# Found image with ID "20201001202439-161"!
# Converted and stored annotation with ID "6609" as a YOLOv5 annotation!
# Found image with ID "20201001202439-171"!
# Converted and stored annotation with ID "6610" as a YOLOv5 annotation!
# Found image with ID "20201001202439-181"!
# Converted and stored annotation with ID "6611" as a YOLOv5 annotation!
# Found image with ID "20201001202439-191"!
# Converted and stored annotation with ID "6612" as a YOLOv5 annotation!
# Found image with ID "20201001202439-201"!
# Converted and stored annotation with ID "6613" as a YOLOv5 annotation!
# Found image with ID "20201001202439-211"!
# Converted and stored annotation with ID "6614" as a YOLOv5 annotation!
# Found image with ID "20201001202439-221"!
# Converted and stored annotation with ID "6615" as a YOLOv5 annotation!
# Found image with ID "20201001202439-231"!
# Converted and stored annotation with ID "6616" as a YOLOv5 annotation!
# Found image with ID "20201001202439-241"!
# Converted and stored annotation with ID "6617" as a YOLOv5 annotation!
# Found image with ID "20201001202439-251"!
# Converted and stored annotation with ID "6618" as a YOLOv5 annotation!
# Found image with ID "20201001202439-261"!
# Converted and stored annotation with ID "6619" as a YOLOv5 annotation!
# Found image with ID "20201001202439-271"!
# Converted and stored annotation with ID "6620" as a YOLOv5 annotation!
# Found image with ID "20201001202439-281"!
# Converted and stored annotation with ID "6621" as a YOLOv5 annotation!
# Found image with ID "20201001202439-291"!
# Converted and stored annotation with ID "6622" as a YOLOv5 annotation!
# Found image with ID "20201001202439-301"!
# Converted and stored annotation with ID "6623" as a YOLOv5 annotation!
# Found image with ID "20201001202439-311"!
# Converted and stored annotation with ID "6624" as a YOLOv5 annotation!
# Found image with ID "20201001202439-321"!
# Converted and stored annotation with ID "6625" as a YOLOv5 annotation!
# Found image with ID "20201001202439-331"!
# Converted and stored annotation with ID "6626" as a YOLOv5 annotation!
# Found image with ID "20201001202439-341"!
# Converted and stored annotation with ID "6627" as a YOLOv5 annotation!
# Found image with ID "20201001202439-351"!
# Converted and stored annotation with ID "6628" as a YOLOv5 annotation!
# Found image with ID "20201001202439-361"!
# Converted and stored annotation with ID "6629" as a YOLOv5 annotation!
# Found image with ID "20201001202439-371"!
# Converted and stored annotation with ID "6630" as a YOLOv5 annotation!
# Found image with ID "20201001202439-381"!
# Converted and stored annotation with ID "6631" as a YOLOv5 annotation!
# Found image with ID "20201001202439-391"!
# Converted and stored annotation with ID "6632" as a YOLOv5 annotation!
# Found image with ID "20201001202439-401"!
# Converted and stored annotation with ID "6633" as a YOLOv5 annotation!
# Found image with ID "20201001202439-411"!
# Converted and stored annotation with ID "6634" as a YOLOv5 annotation!
# Found image with ID "20201001202439-421"!
# Converted and stored annotation with ID "6635" as a YOLOv5 annotation!
# Found image with ID "20201001202439-431"!
# Converted and stored annotation with ID "6636" as a YOLOv5 annotation!
# 350 Annotated Images.
# 350 Images.
# 0 Empty Images.

# %%
write_annotations(yolo_annotations, empty_annotations, IMGS, DEST_IMGS, DEST_LABS, debug=debug)
write_labelmap(data_categories, DEST, debug=debug)
# Out:
# Successfully wrote all annotations for image "20200807023726/color/000031.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000041.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000051.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000061.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000071.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000081.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000091.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000101.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000111.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000121.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000131.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000141.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000151.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000161.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000171.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000181.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000191.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000201.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000211.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000221.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000231.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000241.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000251.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000261.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000271.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000281.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000291.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000301.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000311.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000321.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000331.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000341.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000351.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000361.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000371.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000381.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000391.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000401.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000411.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000421.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000431.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000441.jpg"!
# Successfully wrote all annotations for image "20200807023726/color/000451.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000021.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000031.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000041.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000051.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000061.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000071.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000081.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000091.jpg"!
# Successfully wrote all annotations for image "20200807031150/color/000101.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000031.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000041.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000051.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000061.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000071.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000081.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000091.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000101.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000111.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000121.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000131.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000141.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000151.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000161.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000171.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000181.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000191.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000201.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000211.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000221.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000231.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000241.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000251.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000261.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000271.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000281.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000291.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000301.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000311.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000321.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000331.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000341.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000351.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000361.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000371.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000381.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000391.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000401.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000411.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000421.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000431.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000441.jpg"!
# Successfully wrote all annotations for image "20200807061001/color/000451.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000021.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000031.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000041.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000051.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000061.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000071.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000081.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000091.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000101.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000111.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000121.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000131.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000141.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000151.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000161.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000171.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000181.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000191.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000201.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000211.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000221.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000231.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000241.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000251.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000261.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000271.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000281.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000291.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000301.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000311.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000321.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000331.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000341.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000351.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000361.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000371.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000381.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000391.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000401.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000411.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000421.jpg"!
# Successfully wrote all annotations for image "20200830035607/color/000431.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000011.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000021.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000031.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000041.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000051.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000061.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000071.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000081.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000091.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000101.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000111.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000121.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000131.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000141.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000151.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000161.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000171.jpg"!
# Successfully wrote all annotations for image "20200831204330/color/000181.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000031.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000041.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000051.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000061.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000071.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000081.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000091.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000101.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000111.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000121.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000131.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000141.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000151.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000161.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000171.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000181.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000191.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000201.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000211.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000221.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000231.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000241.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000251.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000261.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000271.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000281.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000291.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000301.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000311.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000321.jpg"!
# Successfully wrote all annotations for image "20200927193425/color/000331.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000031.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000041.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000051.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000061.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000071.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000081.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000091.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000101.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000111.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000121.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000131.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000141.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000151.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000161.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000171.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000181.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000191.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000201.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000211.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000221.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000231.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000241.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000251.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000261.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000271.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000281.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000291.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000301.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000311.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000321.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000331.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000341.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000351.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000361.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000371.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000381.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000391.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000401.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000411.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000421.jpg"!
# Successfully wrote all annotations for image "20200929202034/color/000431.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000031.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000041.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000051.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000061.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000071.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000081.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000091.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000101.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000111.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000121.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000131.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000141.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000151.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000161.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000171.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000181.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000191.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000201.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000211.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000221.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000231.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000241.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000251.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000261.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000271.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000281.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000291.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000301.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000311.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000321.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000331.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000341.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000351.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000361.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000371.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000381.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000391.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000401.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000411.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000421.jpg"!
# Successfully wrote all annotations for image "20200930211737/color/000431.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000031.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000041.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000051.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000061.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000071.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000081.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000091.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000101.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000111.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000121.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000131.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000141.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000151.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000161.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000171.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000181.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000191.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000201.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000211.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000221.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000231.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000241.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000251.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000261.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000271.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000281.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000291.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000301.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000311.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000321.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000331.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000341.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000351.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000361.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000371.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000381.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000391.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000401.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000411.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000421.jpg"!
# Successfully wrote all annotations for image "20201001012942/color/000431.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000031.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000041.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000051.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000061.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000071.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000081.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000091.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000101.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000111.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000121.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000131.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000141.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000151.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000161.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000171.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000181.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000191.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000201.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000211.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000221.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000231.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000241.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000251.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000261.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000271.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000281.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000291.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000301.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000311.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000321.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000331.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000341.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000351.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000361.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000371.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000381.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000391.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000401.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000411.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000421.jpg"!
# Successfully wrote all annotations for image "20201001202439/color/000431.jpg"!
# labelmap.txt already exists!
